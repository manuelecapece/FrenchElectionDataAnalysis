# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelecapece/Unibas-Progetto-Big-data-2022-23/blob/main/QueryGianfrancoCanora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab.data_table import DataTable
from google.colab import drive
from google.colab import files

# %%
drive.mount('/content/drive')
pd.set_option('display.max_columns', None)
DataTable.max_columns = 99
# Out:
# Mounted at /content/drive

# %%
path_job = '/content/drive/Shareddrives/Progetto Big Data/DataSet Puliti/labouref-france-departement-quarter-jobseeker_cleaned.csv'
df_job = pd.read_csv(path_job, sep = ';')

# %%
df_job.head()
# Out:
#         Date Catégorie Tranche d'âge  Nb moyen demandeur emploi  \
# 0 2002-04-01         B   Indifférent                       2310
# 1 2007-10-01         B   Indifférent                       2900
# 2 2012-10-01         B   Indifférent                       4080
# 3 2017-01-01         B   Indifférent                       4810
# 4 2017-07-01         B   Indifférent                       4950
#
#    Différence Nb demandeur emploi trimestre précédent  \
# 0                                               30.0
# 1                                                0.0
# 2                                               10.0
# 3                                              -10.0
# 4                                              130.0
#
#   Code Officiel Département  Code Officiel Région Nom Officiel Région  \
# 0                        11                    76           Occitanie
# 1                        11                    76           Occitanie
# 2                        11                    76           Occitanie
# 3                        11                    76           Occitanie
# 4                        11                    76           Occitanie
#
#   Code Iso 3166-3 Zone Nom Officiel Département  Période Trimestre
# 0                  FXX                     Aude     2002        T2
# 1                  FXX                     Aude     2007        T4
# 2                  FXX                     Aude     2012        T4
# 3                  FXX                     Aude     2017        T1
# 4                  FXX                     Aude     2017        T3

# %%
df_job.dtypes
# Out:
# Date                                                  datetime64[ns]
# Catégorie                                                     string
# Tranche d'âge                                                 string
# Nb moyen demandeur emploi                                      int64
# Différence Nb demandeur emploi trimestre précédent           float64
# Code Officiel Département                                     string
# Code Officiel Région                                           int64
# Nom Officiel Région                                           string
# Code Iso 3166-3 Zone                                          string
# Nom Officiel Département                                      string
# Période                                                        int64
# Trimestre                                                     string
# dtype: object

# %%
df_job[['Trimestre','Catégorie','Tranche d\'âge','Nom Officiel Région','Code Iso 3166-3 Zone','Nom Officiel Département','Code Officiel Département']] = df_job[['Trimestre','Catégorie','Tranche d\'âge','Nom Officiel Région','Code Iso 3166-3 Zone','Nom Officiel Département','Code Officiel Département']].astype("string")
df_job['Période'] = df_job['Période'].astype('int64')
df_job['Date'] = pd.to_datetime(df_job['Date'])

# %% [markdown]
# ## I 20 dipartimenti con la minore disoccupazione

# %%
#Numero medio di persone in cerca di lavoro
# Nb moyen demandeur emploi

#Prendo gli ultimi sondaggi dei dipartimenti ed elimino i precedenti 
df_job= df_job.sort_values(by=['Date']).drop_duplicates(subset='Nom Officiel Département', keep='last')

# %%
df_job = df_job.sort_values('Nb moyen demandeur emploi')
df_job.head(20)
# Out:
#             Date Catégorie       Tranche d'âge  Nb moyen demandeur emploi  \
# 25904 2022-10-01       ABC     Moins de 25 ans                       1310
# 22772 2022-10-01         D         Indifférent                       1670
# 19448 2022-10-01         E         Indifférent                       1720
# 5770  2022-10-01         B         Indifférent                       1870
# 44280 2022-10-01         C         Indifférent                       2120
# 18710 2022-10-01         E         Indifférent                       2370
# 39098 2022-10-01       ABC     Moins de 25 ans                       3150
# 22853 2022-10-01         D         Indifférent                       3430
# 29123 2022-10-01       ABC     Moins de 25 ans                       3680
# 10641 2022-10-01       ABC  Entre 25 et 49 ans                       3760
# 43974 2022-10-01       ABC     Moins de 25 ans                       4030
# 34263 2022-10-01       ABC         Indifférent                       4060
# 6562  2022-10-01       ABC     Moins de 25 ans                       4470
# 44083 2022-10-01       ABC      Plus de 50 ans                       4690
# 26681 2022-10-01       ABC     Moins de 25 ans                       4930
# 44033 2022-10-01       ABC     Moins de 25 ans                       5140
# 4150  2022-10-01         E         Indifférent                       5400
# 13635 2022-10-01         C         Indifférent                       5630
# 27282 2022-10-01         C         Indifférent                       6910
# 15003 2022-10-01       ABC  Entre 25 et 49 ans                       7640
#
#        Différence Nb demandeur emploi trimestre précédent  \
# 25904                                              -10.0
# 22772                                             -110.0
# 19448                                              -50.0
# 5770                                                10.0
# 44280                                              110.0
# 18710                                              -20.0
# 39098                                               20.0
# 22853                                             -130.0
# 29123                                              -10.0
# 10641                                              -80.0
# 43974                                              210.0
# 34263                                               50.0
# 6562                                               160.0
# 44083                                              -20.0
# 26681                                              100.0
# 44033                                               50.0
# 4150                                              -160.0
# 13635                                              150.0
# 27282                                              -50.0
# 15003                                               30.0
#
#       Code Officiel Département  Code Officiel Région  \
# 25904                        32                    76
# 22772                        79                    75
# 19448                        19                    75
# 5770                        973                     3
# 44280                        23                    75
# 18710                        86                    75
# 39098                        73                    84
# 22853                        66                    76
# 29123                        16                    75
# 10641                        15                    84
# 43974                        40                    75
# 34263                        48                    76
# 6562                         11                    76
# 44083                        04                    93
# 26681                       972                     2
# 44033                        01                    84
# 4150                         30                    76
# 13635                        43                    84
# 27282                        53                    52
# 15003                        46                    76
#
#               Nom Officiel Région Code Iso 3166-3 Zone  \
# 25904                   Occitanie                  FXX
# 22772          Nouvelle-Aquitaine                  FXX
# 19448          Nouvelle-Aquitaine                  FXX
# 5770                       Guyane                  GUF
# 44280          Nouvelle-Aquitaine                  FXX
# 18710          Nouvelle-Aquitaine                  FXX
# 39098        Auvergne-Rhône-Alpes                  FXX
# 22853                   Occitanie                  FXX
# 29123          Nouvelle-Aquitaine                  FXX
# 10641        Auvergne-Rhône-Alpes                  FXX
# 43974          Nouvelle-Aquitaine                  FXX
# 34263                   Occitanie                  FXX
# 6562                    Occitanie                  FXX
# 44083  Provence-Alpes-Côte d'Azur                  FXX
# 26681                  Martinique                  MTQ
# 44033        Auvergne-Rhône-Alpes                  FXX
# 4150                    Occitanie                  FXX
# 13635        Auvergne-Rhône-Alpes                  FXX
# 27282            Pays de la Loire                  FXX
# 15003                   Occitanie                  FXX
#
#       Nom Officiel Département  Période Trimestre
# 25904                     Gers     2022        T4
# 22772              Deux-Sèvres     2022        T4
# 19448                  Corrèze     2022        T4
# 5770                    Guyane     2022        T4
# 44280                   Creuse     2022        T4
# 18710                   Vienne     2022        T4
# 39098                   Savoie     2022        T4
# 22853      Pyrénées-Orientales     2022        T4
# 29123                 Charente     2022        T4
# 10641                   Cantal     2022        T4
# 43974                   Landes     2022        T4
# 34263                   Lozère     2022        T4
# 6562                      Aude     2022        T4
# 44083  Alpes-de-Haute-Provence     2022        T4
# 26681               Martinique     2022        T4
# 44033                      Ain     2022        T4
# 4150                      Gard     2022        T4
# 13635              Haute-Loire     2022        T4
# 27282                  Mayenne     2022        T4
# 15003                      Lot     2022        T4

# %% [markdown]
# ## I 20 dipartimenti con il maggiore reddito pro capite

# %% [markdown]
# ## I 20 dipartimenti con il minore reddito pro capite

# %% [markdown]
# ## I 20 dipartimenti con la maggiore percentuale di vaccinazioni COVID

# %% [markdown]
# ## I 20 dipartimenti con la minore percentuale di vaccinazioni COVID
