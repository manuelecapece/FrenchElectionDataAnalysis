# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # **1.Data Preparation**

# %%
path = '/content/drive/Shareddrives/Progetto Big Data/DataSet/elections-france-legislatives-2022-2nd-tour-par-bureau-de-vote.csv'
df = pd.read_csv(path, sep = ';')

# %% [markdown]
# ## 1.1.Comprensione del dataSet

# %%
df.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  76         Seine-Maritime                           2
# 1                  76         Seine-Maritime                          10
# 2                  76         Seine-Maritime                          10
# 3                  76         Seine-Maritime                           5
# 4                  76         Seine-Maritime                           1
#
#   Libellé de la circonscription Code de la commune    Libellé de la commune  \
# 0          2ème circonscription              76412   Martainville-Epreville
# 1         10ème circonscription              76417                Maucomble
# 2         10ème circonscription              76430       Mesnil-Follemprise
# 3          5ème circonscription              76436  Le Mesnil-sous-Jumièges
# 4          1ère circonscription              76451        Mont-Saint-Aignan
#
#   Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0              1       620          349      56.29      271      43.71
# 1              1       312          135      43.27      177      56.73
# 2              1        98           44      44.90       54      55.10
# 3              1       501          257      51.30      244      48.70
# 4             14      1052          405      38.50      647      61.50
#
#    Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  Exprimés  \
# 0      14          2.26          5.17     5        0.81        1.85       252
# 1      10          3.21          5.65     5        1.60        2.82       162
# 2       7          7.14         12.96     0        0.00        0.00        47
# 3      18          3.59          7.38     1        0.20        0.41       225
# 4      23          2.19          3.55    10        0.95        1.55       614
#
#    % Exp/Ins  % Exp/Vot  N°Panneau Sexe      Nom      Prénom Nuance  Voix  \
# 0      40.65      92.99          3    M    DUVAL   Sébastien    NUP   119
# 1      51.92      91.53          8    F   THOMAS       Anaïs     RN    91
# 2      47.96      87.04          8    F   THOMAS       Anaïs     RN    23
# 3      44.91      92.21          5    M  MONTIER  Jean-Cyril     RN   111
# 4      58.37      94.90          9    M     ADAM      Damien    ENS   458
#
#    % Voix/Ins % Voix/Exp  Code Officiel EPCI          Nom Officiel EPCI  \
# 0       19.19      47,22         200070449.0        CC Inter-Caux-Vexin
# 1       29.17      56,17         200070068.0    CC Communauté Bray-Eawy
# 2       23.47      48,94         200070068.0    CC Communauté Bray-Eawy
# 3       22.16      49,33         200023414.0  Métropole Rouen Normandie
# 4       43.54      74,59         200023414.0  Métropole Rouen Normandie
#
#    Code Officiel Région Nom Officiel Région             location  \
# 0                  28.0           Normandie  49.459799, 1.294886
# 1                  28.0           Normandie                  NaN
# 2                  28.0           Normandie  49.773247, 1.299788
# 3                  28.0           Normandie  49.411874, 0.857707
# 4                  28.0           Normandie   49.46335, 1.089179
#
#         Libellé du bureau de vote scrutin_code
# 0                   BUREAU UNIQUE       LG2022
# 1                             NaN       LG2022
# 2    MAIRIE DE MESNIL FOLLEMPRISE       LG2022
# 3  MAIRIE DU MESNIL SOUS JUMIEGES       LG2022
# 4         MAISON DES ASSOCIATIONS       LG2022

# %%
df['% Voix/Exp'] = df['% Voix/Exp'].astype('string')
df['% Voix/Exp'] = df['% Voix/Exp'].replace(',', '.',regex = True)
df.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  76         Seine-Maritime                           2
# 1                  76         Seine-Maritime                          10
# 2                  76         Seine-Maritime                          10
# 3                  76         Seine-Maritime                           5
# 4                  76         Seine-Maritime                           1
#
#   Libellé de la circonscription Code de la commune    Libellé de la commune  \
# 0          2ème circonscription              76412   Martainville-Epreville
# 1         10ème circonscription              76417                Maucomble
# 2         10ème circonscription              76430       Mesnil-Follemprise
# 3          5ème circonscription              76436  Le Mesnil-sous-Jumièges
# 4          1ère circonscription              76451        Mont-Saint-Aignan
#
#   Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0              1       620          349      56.29      271      43.71
# 1              1       312          135      43.27      177      56.73
# 2              1        98           44      44.90       54      55.10
# 3              1       501          257      51.30      244      48.70
# 4             14      1052          405      38.50      647      61.50
#
#    Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  Exprimés  \
# 0      14          2.26          5.17     5        0.81        1.85       252
# 1      10          3.21          5.65     5        1.60        2.82       162
# 2       7          7.14         12.96     0        0.00        0.00        47
# 3      18          3.59          7.38     1        0.20        0.41       225
# 4      23          2.19          3.55    10        0.95        1.55       614
#
#    % Exp/Ins  % Exp/Vot  N°Panneau Sexe      Nom      Prénom Nuance  Voix  \
# 0      40.65      92.99          3    M    DUVAL   Sébastien    NUP   119
# 1      51.92      91.53          8    F   THOMAS       Anaïs     RN    91
# 2      47.96      87.04          8    F   THOMAS       Anaïs     RN    23
# 3      44.91      92.21          5    M  MONTIER  Jean-Cyril     RN   111
# 4      58.37      94.90          9    M     ADAM      Damien    ENS   458
#
#    % Voix/Ins % Voix/Exp  Code Officiel EPCI          Nom Officiel EPCI  \
# 0       19.19      47.22         200070449.0        CC Inter-Caux-Vexin
# 1       29.17      56.17         200070068.0    CC Communauté Bray-Eawy
# 2       23.47      48.94         200070068.0    CC Communauté Bray-Eawy
# 3       22.16      49.33         200023414.0  Métropole Rouen Normandie
# 4       43.54      74.59         200023414.0  Métropole Rouen Normandie
#
#    Code Officiel Région Nom Officiel Région             location  \
# 0                  28.0           Normandie  49.459799, 1.294886
# 1                  28.0           Normandie                  NaN
# 2                  28.0           Normandie  49.773247, 1.299788
# 3                  28.0           Normandie  49.411874, 0.857707
# 4                  28.0           Normandie   49.46335, 1.089179
#
#         Libellé du bureau de vote scrutin_code
# 0                   BUREAU UNIQUE       LG2022
# 1                             NaN       LG2022
# 2    MAIRIE DE MESNIL FOLLEMPRISE       LG2022
# 3  MAIRIE DU MESNIL SOUS JUMIEGES       LG2022
# 4         MAISON DES ASSOCIATIONS       LG2022

# %%
df.describe(include = 'all')
# Out:
#        Code du département Libellé du département  Code de la circonscription  \
# count               139650                 139650               139650.000000
# unique                  97                    107                         NaN
# top                     97                   Nord                         NaN
# freq                  5482                   4004                         NaN
# mean                   NaN                    NaN                    4.148407
# std                    NaN                    NaN                    3.256630
# min                    NaN                    NaN                    1.000000
# 25%                    NaN                    NaN                    2.000000
# 50%                    NaN                    NaN                    3.000000
# 75%                    NaN                    NaN                    5.000000
# max                    NaN                    NaN                   21.000000
#
#        Libellé de la circonscription Code de la commune Libellé de la commune  \
# count                         139650             139650                139650
# unique                            22              35088                 32894
# top             2ème circonscription              75056                 Paris
# freq                           27808               1528                  1528
# mean                             NaN                NaN                   NaN
# std                              NaN                NaN                   NaN
# min                              NaN                NaN                   NaN
# 25%                              NaN                NaN                   NaN
# 50%                              NaN                NaN                   NaN
# 75%                              NaN                NaN                   NaN
# max                              NaN                NaN                   NaN
#
#        Code du b.vote       Inscrits    Abstentions      % Abs/Ins  \
# count          139650  139650.000000  139650.000000  139650.000000
# unique           1623            NaN            NaN            NaN
# top                 1            NaN            NaN            NaN
# freq            71009            NaN            NaN            NaN
# mean              NaN     698.532252     374.811106      50.832465
# std               NaN     994.579977     714.686682       9.578200
# min               NaN       0.000000       0.000000       0.000000
# 25%               NaN     295.000000     140.250000      45.030000
# 50%               NaN     752.000000     388.000000      50.720000
# 75%               NaN     974.000000     526.000000      56.340000
# max               NaN  125011.000000   94502.000000     100.000000
#
#               Votants      % Vot/Ins         Blancs   % Blancs/Ins  \
# count   139650.000000  139650.000000  139650.000000  139650.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean       323.721146      49.164701      17.705678       2.904101
# std        309.160346       9.577959      16.232445       2.097661
# min          0.000000       0.000000       0.000000       0.000000
# 25%        150.000000      43.660000       7.000000       1.620000
# 50%        326.000000      49.280000      15.000000       2.480000
# 75%        455.000000      54.970000      25.000000       3.630000
# max      32306.000000     100.000000    1566.000000      43.480000
#
#          % Blancs/Vot           Nuls     % Nuls/Ins     % Nuls/Vot  \
# count   139650.000000  139650.000000  139650.000000  139650.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         5.871146       6.895825       1.150565       2.326808
# std          3.748607       6.078768       1.126502       2.061494
# min          0.000000       0.000000       0.000000       0.000000
# 25%          3.480000       2.000000       0.500000       1.080000
# 50%          5.210000       6.000000       0.910000       1.920000
# 75%          7.440000      10.000000       1.470000       3.050000
# max         63.160000      78.000000      20.000000      36.070000
#
#              Exprimés      % Exp/Ins      % Exp/Vot      N°Panneau    Sexe  \
# count   139650.000000  139650.000000  139650.000000  139650.000000  139650
# unique            NaN            NaN            NaN            NaN       2
# top               NaN            NaN            NaN            NaN       M
# freq              NaN            NaN            NaN            NaN   81642
# mean       299.119642      45.110031      91.796394       5.799327     NaN
# std        295.151161       9.000584       4.579536       3.355012     NaN
# min          0.000000       0.000000       0.000000       1.000000     NaN
# 25%        137.000000      39.800000      89.780000       3.000000     NaN
# 50%        299.000000      45.000000      92.590000       6.000000     NaN
# 75%        420.000000      50.530000      94.780000       8.000000     NaN
# max      31251.000000     100.000000     100.000000      16.000000     NaN
#
#            Nom    Prénom  Nuance           Voix     % Voix/Ins % Voix/Exp  \
# count   139650    139650  139650  139650.000000  139650.000000     139650
# unique    1091       499      12            NaN            NaN       7573
# top     MARTIN  Philippe     ENS            NaN            NaN      50.00
# freq       655      2805   48200            NaN            NaN       1258
# mean       NaN       NaN     NaN     148.590254      22.335055        NaN
# std        NaN       NaN     NaN     156.029194       7.663115        NaN
# min        NaN       NaN     NaN       0.000000       0.000000        NaN
# 25%        NaN       NaN     NaN      64.000000      17.320000        NaN
# 50%        NaN       NaN     NaN     138.000000      21.710000        NaN
# 75%        NaN       NaN     NaN     208.000000      26.540000        NaN
# max        NaN       NaN     NaN   18828.000000     100.000000        NaN
#
#         Code Officiel EPCI         Nom Officiel EPCI  Code Officiel Région  \
# count         1.381700e+05                    138170         138244.000000
# unique                 NaN                      1249                   NaN
# top                    NaN  Métropole du Grand Paris                   NaN
# freq                   NaN                      6956                   NaN
# mean          2.149325e+08                       NaN             51.041955
# std           2.121826e+07                       NaN             33.680359
# min           2.000002e+08                       NaN              1.000000
# 25%           2.000548e+08                       NaN             28.000000
# 50%           2.000696e+08                       NaN             44.000000
# 75%           2.431005e+08                       NaN             76.000000
# max           2.497401e+08                       NaN            978.000000
#
#        Nom Officiel Région              location Libellé du bureau de vote  \
# count               138244                132485                    133393
# unique                  21                 42231                     29445
# top              Grand Est  44.851895, -0.587877                    MAIRIE
# freq                 15270                   296                     21280
# mean                   NaN                   NaN                       NaN
# std                    NaN                   NaN                       NaN
# min                    NaN                   NaN                       NaN
# 25%                    NaN                   NaN                       NaN
# 50%                    NaN                   NaN                       NaN
# 75%                    NaN                   NaN                       NaN
# max                    NaN                   NaN                       NaN
#
#        scrutin_code
# count        139650
# unique            1
# top          LG2022
# freq         139650
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139650 entries, 0 to 139649
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Code du département            139650 non-null  object
#  1   Libellé du département         139650 non-null  object
#  2   Code de la circonscription     139650 non-null  int64
#  3   Libellé de la circonscription  139650 non-null  object
#  4   Code de la commune             139650 non-null  object
#  5   Libellé de la commune          139650 non-null  object
#  6   Code du b.vote                 139650 non-null  object
#  7   Inscrits                       139650 non-null  int64
#  8   Abstentions                    139650 non-null  int64
#  9   % Abs/Ins                      139650 non-null  float64
#  10  Votants                        139650 non-null  int64
#  11  % Vot/Ins                      139650 non-null  float64
#  12  Blancs                         139650 non-null  int64
#  13  % Blancs/Ins                   139650 non-null  float64
#  14  % Blancs/Vot                   139650 non-null  float64
#  15  Nuls                           139650 non-null  int64
#  16  % Nuls/Ins                     139650 non-null  float64
#  17  % Nuls/Vot                     139650 non-null  float64
#  18  Exprimés                       139650 non-null  int64
#  19  % Exp/Ins                      139650 non-null  float64
#  20  % Exp/Vot                      139650 non-null  float64
#  21  N°Panneau                      139650 non-null  int64
#  22  Sexe                           139650 non-null  object
#  23  Nom                            139650 non-null  object
#  24  Prénom                         139650 non-null  object
#  25  Nuance                         139650 non-null  object
#  26  Voix                           139650 non-null  int64
#  27  % Voix/Ins                     139650 non-null  float64
#  28  % Voix/Exp                     139650 non-null  string
#  29  Code Officiel EPCI             138170 non-null  float64
#  30  Nom Officiel EPCI              138170 non-null  object
#  31  Code Officiel Région           138244 non-null  float64
#  32  Nom Officiel Région            138244 non-null  object
#  33  location                       132485 non-null  object
#  34  Libellé du bureau de vote      133393 non-null  object
#  35  scrutin_code                   139650 non-null  object
# dtypes: float64(11), int64(9), object(15), string(1)
# memory usage: 38.4+ MB

# %%
df_separato = df['location'].str.split(',', expand=True)
df_separato.columns = ['Latitudine', 'Longitudine']
df_separato.head()
# Out:
#   Latitudine Longitudine
# 0  49.459799    1.294886
# 1        NaN         NaN
# 2  49.773247    1.299788
# 3  49.411874    0.857707
# 4   49.46335    1.089179

# %%
df = pd.concat([df, df_separato], axis=1)
df = df.drop('location',axis = 1)
df.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  76         Seine-Maritime                           2
# 1                  76         Seine-Maritime                          10
# 2                  76         Seine-Maritime                          10
# 3                  76         Seine-Maritime                           5
# 4                  76         Seine-Maritime                           1
#
#   Libellé de la circonscription Code de la commune    Libellé de la commune  \
# 0          2ème circonscription              76412   Martainville-Epreville
# 1         10ème circonscription              76417                Maucomble
# 2         10ème circonscription              76430       Mesnil-Follemprise
# 3          5ème circonscription              76436  Le Mesnil-sous-Jumièges
# 4          1ère circonscription              76451        Mont-Saint-Aignan
#
#   Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0              1       620          349      56.29      271      43.71
# 1              1       312          135      43.27      177      56.73
# 2              1        98           44      44.90       54      55.10
# 3              1       501          257      51.30      244      48.70
# 4             14      1052          405      38.50      647      61.50
#
#    Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  Exprimés  \
# 0      14          2.26          5.17     5        0.81        1.85       252
# 1      10          3.21          5.65     5        1.60        2.82       162
# 2       7          7.14         12.96     0        0.00        0.00        47
# 3      18          3.59          7.38     1        0.20        0.41       225
# 4      23          2.19          3.55    10        0.95        1.55       614
#
#    % Exp/Ins  % Exp/Vot  N°Panneau Sexe      Nom      Prénom Nuance  Voix  \
# 0      40.65      92.99          3    M    DUVAL   Sébastien    NUP   119
# 1      51.92      91.53          8    F   THOMAS       Anaïs     RN    91
# 2      47.96      87.04          8    F   THOMAS       Anaïs     RN    23
# 3      44.91      92.21          5    M  MONTIER  Jean-Cyril     RN   111
# 4      58.37      94.90          9    M     ADAM      Damien    ENS   458
#
#    % Voix/Ins % Voix/Exp  Code Officiel EPCI          Nom Officiel EPCI  \
# 0       19.19      47.22         200070449.0        CC Inter-Caux-Vexin
# 1       29.17      56.17         200070068.0    CC Communauté Bray-Eawy
# 2       23.47      48.94         200070068.0    CC Communauté Bray-Eawy
# 3       22.16      49.33         200023414.0  Métropole Rouen Normandie
# 4       43.54      74.59         200023414.0  Métropole Rouen Normandie
#
#    Code Officiel Région Nom Officiel Région       Libellé du bureau de vote  \
# 0                  28.0           Normandie                   BUREAU UNIQUE
# 1                  28.0           Normandie                             NaN
# 2                  28.0           Normandie    MAIRIE DE MESNIL FOLLEMPRISE
# 3                  28.0           Normandie  MAIRIE DU MESNIL SOUS JUMIEGES
# 4                  28.0           Normandie         MAISON DES ASSOCIATIONS
#
#   scrutin_code Latitudine Longitudine
# 0       LG2022  49.459799    1.294886
# 1       LG2022        NaN         NaN
# 2       LG2022  49.773247    1.299788
# 3       LG2022  49.411874    0.857707
# 4       LG2022   49.46335    1.089179

# %% [markdown]
# ## 1.2.Gestione dei valori nulli

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Code du département  Libellé du département  Code de la circonscription  \
# 0                False                   False                       False
# 1                False                   False                       False
# 2                False                   False                       False
# 3                False                   False                       False
# 4                False                   False                       False
#
#    Libellé de la circonscription  Code de la commune  Libellé de la commune  \
# 0                          False               False                  False
# 1                          False               False                  False
# 2                          False               False                  False
# 3                          False               False                  False
# 4                          False               False                  False
#
#    Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0           False     False        False      False    False      False
# 1           False     False        False      False    False      False
# 2           False     False        False      False    False      False
# 3           False     False        False      False    False      False
# 4           False     False        False      False    False      False
#
#    Blancs  % Blancs/Ins  % Blancs/Vot   Nuls  % Nuls/Ins  % Nuls/Vot  \
# 0   False         False         False  False       False       False
# 1   False         False         False  False       False       False
# 2   False         False         False  False       False       False
# 3   False         False         False  False       False       False
# 4   False         False         False  False       False       False
#
#    Exprimés  % Exp/Ins  % Exp/Vot  N°Panneau   Sexe    Nom  Prénom  Nuance  \
# 0     False      False      False      False  False  False   False   False
# 1     False      False      False      False  False  False   False   False
# 2     False      False      False      False  False  False   False   False
# 3     False      False      False      False  False  False   False   False
# 4     False      False      False      False  False  False   False   False
#
#     Voix  % Voix/Ins  % Voix/Exp  Code Officiel EPCI  Nom Officiel EPCI  \
# 0  False       False       False               False              False
# 1  False       False       False               False              False
# 2  False       False       False               False              False
# 3  False       False       False               False              False
# 4  False       False       False               False              False
#
#    Code Officiel Région  Nom Officiel Région  Libellé du bureau de vote  \
# 0                 False                False                      False
# 1                 False                False                       True
# 2                 False                False                      False
# 3                 False                False                      False
# 4                 False                False                      False
#
#    scrutin_code  Latitudine  Longitudine
# 0         False       False        False
# 1         False        True         True
# 2         False       False        False
# 3         False       False        False
# 4         False       False        False

# %%
for column in missing_data.columns.values.tolist():
    #print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# False    139650
# Name: Code du département, dtype: int64
#
# False    139650
# Name: Libellé du département, dtype: int64
#
# False    139650
# Name: Code de la circonscription, dtype: int64
#
# False    139650
# Name: Libellé de la circonscription, dtype: int64
#
# False    139650
# Name: Code de la commune, dtype: int64
#
# False    139650
# Name: Libellé de la commune, dtype: int64
#
# False    139650
# Name: Code du b.vote, dtype: int64
#
# False    139650
# Name: Inscrits, dtype: int64
#
# False    139650
# Name: Abstentions, dtype: int64
#
# False    139650
# Name: % Abs/Ins, dtype: int64
#
# False    139650
# Name: Votants, dtype: int64
#
# False    139650
# Name: % Vot/Ins, dtype: int64
#
# False    139650
# Name: Blancs, dtype: int64
#
# False    139650
# Name: % Blancs/Ins, dtype: int64
#
# False    139650
# Name: % Blancs/Vot, dtype: int64
#
# False    139650
# Name: Nuls, dtype: int64
#
# False    139650
# Name: % Nuls/Ins, dtype: int64
#
# False    139650
# Name: % Nuls/Vot, dtype: int64
#
# False    139650
# Name: Exprimés, dtype: int64
#
# False    139650
# Name: % Exp/Ins, dtype: int64
#
# False    139650
# Name: % Exp/Vot, dtype: int64
#
# False    139650
# Name: N°Panneau, dtype: int64
#
# False    139650
# Name: Sexe, dtype: int64
#
# False    139650
# Name: Nom, dtype: int64
#
# False    139650
# Name: Prénom, dtype: int64
#
# False    139650
# Name: Nuance, dtype: int64
#
# False    139650
# Name: Voix, dtype: int64
#
# False    139650
# Name: % Voix/Ins, dtype: int64
#
# False    139650
# Name: % Voix/Exp, dtype: int64
#
# False    138170
# True       1480
# Name: Code Officiel EPCI, dtype: int64
#
# False    138170
# True       1480
# Name: Nom Officiel EPCI, dtype: int64
#
# False    138244
# True       1406
# Name: Code Officiel Région, dtype: int64
#
# False    138244
# True       1406
# Name: Nom Officiel Région, dtype: int64
#
# False    133393
# True       6257
# Name: Libellé du bureau de vote, dtype: int64
#
# False    139650
# Name: scrutin_code, dtype: int64
#
# False    132485
# True       7165
# Name: Latitudine, dtype: int64
#
# False    132485
# True       7165
# Name: Longitudine, dtype: int64

# %% [markdown]
# ## 1.3.Gestione dei tipi

# %%
df.dtypes
# Out:
# Code du département               object
# Libellé du département            object
# Code de la circonscription         int64
# Libellé de la circonscription     object
# Code de la commune                object
# Libellé de la commune             object
# Code du b.vote                    object
# Inscrits                           int64
# Abstentions                        int64
# % Abs/Ins                        float64
# Votants                            int64
# % Vot/Ins                        float64
# Blancs                             int64
# % Blancs/Ins                     float64
# % Blancs/Vot                     float64
# Nuls                               int64
# % Nuls/Ins                       float64
# % Nuls/Vot                       float64
# Exprimés                           int64
# % Exp/Ins                        float64
# % Exp/Vot                        float64
# N°Panneau                          int64
# Sexe                              object
# Nom                               object
# Prénom                            object
# Nuance                            object
# Voix                               int64
# % Voix/Ins                       float64
# % Voix/Exp                        string
# Code Officiel EPCI               float64
# Nom Officiel EPCI                 object
# Code Officiel Région             float64
# Nom Officiel Région               object
# Libellé du bureau de vote         object
# scrutin_code                      object
# Latitudine                        object
# Longitudine                       object
# dtype: object

# %%
df[['Code du département','Code de la commune', 'Code du b.vote']] = df[['Code du département','Code de la commune', 'Code du b.vote']].astype("string")
df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune', 
    'Sexe','Nom','Prénom','Nuance','Nom Officiel Région',
    'Libellé du bureau de vote','scrutin_code']] = df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune', 
                                                        'Sexe','Nom','Prénom','Nuance','Nom Officiel Région',
                                                        'Libellé du bureau de vote','scrutin_code']].astype("string")
df[['Latitudine','Longitudine','% Voix/Exp']] = df[['Latitudine','Longitudine','% Voix/Exp']].astype('float')

# %%
df.dtypes
# Out:
# Code du département               string
# Libellé du département            string
# Code de la circonscription         int64
# Libellé de la circonscription     string
# Code de la commune                string
# Libellé de la commune             string
# Code du b.vote                    string
# Inscrits                           int64
# Abstentions                        int64
# % Abs/Ins                        float64
# Votants                            int64
# % Vot/Ins                        float64
# Blancs                             int64
# % Blancs/Ins                     float64
# % Blancs/Vot                     float64
# Nuls                               int64
# % Nuls/Ins                       float64
# % Nuls/Vot                       float64
# Exprimés                           int64
# % Exp/Ins                        float64
# % Exp/Vot                        float64
# N°Panneau                          int64
# Sexe                              string
# Nom                               string
# Prénom                            string
# Nuance                            string
# Voix                               int64
# % Voix/Ins                       float64
# % Voix/Exp                       float64
# Code Officiel EPCI               float64
# Nom Officiel EPCI                 object
# Code Officiel Région             float64
# Nom Officiel Région               string
# Libellé du bureau de vote         string
# scrutin_code                      string
# Latitudine                       float64
# Longitudine                      float64
# dtype: object
