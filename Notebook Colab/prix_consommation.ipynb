# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelecapece/Unibas-Progetto-Big-data-2022-23/blob/main/Notebook%20Colab/prix_consommation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1.Data Preparation**

# %%
path = '/content/drive/Shareddrives/Progetto Big Data/DataSet/economicref-france-indice-prix-consommation.csv'
df = pd.read_csv(path, sep = ';')

# %% [markdown]
# ## 1.1.Comprensione del dataSet

# %%
df.tail()
# Out:
#           Période                                             Indice  Valeur  \
# 433778 2011-04-01  Indice des prix à la consommation - Base 2015 ...   99.79
# 433779 2011-04-01  Indice des prix à la consommation - Base 2015 ...   97.64
# 433780 2011-04-01  Indice des prix à la consommation - Base 2015 ...    0.30
# 433781 2011-05-01  Indice des prix à la consommation - Base 2015 ...  102.22
# 433782 2011-05-01  Indice des prix à la consommation - Base 2015 ...    0.00
#
#        Code                               Type              Sous-type  \
# 433778    A  Indice des prix à la consommation     Valeurs mensuelles
# 433779    A  Indice des prix à la consommation     Valeurs mensuelles
# 433780    A  Indice des prix à la consommation  Variations mensuelles
# 433781    A  Indice des prix à la consommation     Valeurs mensuelles
# 433782    A  Indice des prix à la consommation      Glissement annuel
#
#              Base            Population         Zone concernée Code COICOP  \
# ...

# %%
df.describe(include = 'all')
# Out:
#         Période                                             Indice  \
# count    433783                                             433783
# unique      399                                               1211
# top     2023-02  Indice des prix à la consommation - Base 2015 ...
# freq       1178                                                399
# mean        NaN                                                NaN
# std         NaN                                                NaN
# min         NaN                                                NaN
# 25%         NaN                                                NaN
# 50%         NaN                                                NaN
# 75%         NaN                                                NaN
# max         NaN                                                NaN
#
#                Valeur    Code                               Type  \
# count   433783.000000  433783                             433783
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433783 entries, 0 to 433782
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Période             433783 non-null  object
#  1   Indice              433783 non-null  object
#  2   Valeur              433783 non-null  float64
#  3   Code                433783 non-null  object
#  4   Type                433783 non-null  object
#  5   Sous-type           433783 non-null  object
#  6   Base                433783 non-null  object
#  7   Population          433783 non-null  object
#  8   Zone concernée      433783 non-null  object
#  9   Code COICOP         335478 non-null  object
#  10  Désignation COICOP  433783 non-null  object
#  11  Série arrêtée       433783 non-null  object
#  12  Référence INSEE     433783 non-null  int64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 43.0+ MB

# %% [markdown]
# ## 1.2.Gestione dei valori nulli

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Période  Indice  Valeur   Code   Type  Sous-type   Base  Population  \
# 0    False   False   False  False  False      False  False       False
# 1    False   False   False  False  False      False  False       False
# 2    False   False   False  False  False      False  False       False
# 3    False   False   False  False  False      False  False       False
# 4    False   False   False  False  False      False  False       False
#
#    Zone concernée  Code COICOP  Désignation COICOP  Série arrêtée  \
# 0           False        False               False          False
# 1           False        False               False          False
# 2           False        False               False          False
# 3           False        False               False          False
# 4           False        False               False          False
#
#    Référence INSEE
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
for column in missing_data.columns.values.tolist():
    #print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# False    433783
# Name: Période, dtype: int64
#
# False    433783
# Name: Indice, dtype: int64
#
# False    433783
# Name: Valeur, dtype: int64
#
# False    433783
# Name: Code, dtype: int64
#
# False    433783
# Name: Type, dtype: int64
#
# False    433783
# Name: Sous-type, dtype: int64
#
# False    433783
# Name: Base, dtype: int64
#
# False    433783
# Name: Population, dtype: int64
#
# False    433783
# Name: Zone concernée, dtype: int64
#
# False    335478
# True      98305
# Name: Code COICOP, dtype: int64
#
# False    433783
# Name: Désignation COICOP, dtype: int64
#
# False    433783
# Name: Série arrêtée, dtype: int64
#
# False    433783
# Name: Référence INSEE, dtype: int64

# %% [markdown]
# ## 1.3.Gestione dei tipi

# %%
df.dtypes
# Out:
# Période                object
# Indice                 object
# Valeur                float64
# Code                   object
# Type                   object
# Sous-type              object
# Base                   object
# Population             object
# Zone concernée         object
# Code COICOP            object
# Désignation COICOP     object
# Série arrêtée          object
# Référence INSEE         int64
# dtype: object

# %%
df[['Indice',"Code", "Type",'Sous-type', 'Base', 'Population' ,
    'Zone concernée', 'Code COICOP', 'Désignation COICOP' ]] = df[['Indice',"Code", "Type",'Sous-type', 'Base', 'Population' ,
                                                                   'Zone concernée', 'Code COICOP', 'Désignation COICOP' ]].astype("string")

df['Période'] = pd.to_datetime(df['Période'])

# %%
df.dtypes
# Out:
# Période               datetime64[ns]
# Indice                        string
# Valeur                       float64
# Code                          string
# Type                          string
# Sous-type                     string
# Base                          string
# Population                    string
# Zone concernée                string
# Code COICOP                   string
# Désignation COICOP            string
# Série arrêtée                 object
# Référence INSEE                int64
# dtype: object

# %%
df_intervallo = df[(df['Période'] >= '2022-07-01') & (df['Période'] <= '2023-12-31')]
df_intervallo.shape
# Out:
# (9321, 13)
