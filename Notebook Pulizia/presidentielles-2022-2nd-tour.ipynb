# %%
import pandas as pd
import numpy as np
from google.colab.data_table import DataTable
from google.colab import drive
from google.colab import files

# %%
drive.mount('/content/drive')
pd.set_option('display.max_columns', None)
DataTable.max_columns = 99
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **1.Data Preparation**

# %%
path = '/content/drive/Shareddrives/Progetto Big Data/DataSet/elections-france-presidentielles-2022-2nd-tour-par-bureau-de-vote.csv'
df = pd.read_csv(path, sep = ';')

# %% [markdown]
# ## 1.1.Comprensione del dataSet e sistemazione delle colonne

# %%
df.head(500)
# Out:
#     Code du département Libellé du département  Code de la circonscription  \
# 0                    01                    Ain                           5
# 1                    01                    Ain                           5
# 2                    01                    Ain                           5
# 3                    01                    Ain                           4
# 4                    01                    Ain                           3
# ..                  ...                    ...                         ...
# 495                  24               Dordogne                           3
# 496                  24               Dordogne                           2
# 497                  24               Dordogne                           4
# 498                  21              Côte-d'Or                           5
# 499                  21              Côte-d'Or                           4
#
#     Libellé de la circonscription Code de la commune  \
# 0            5ème circonscription              01004
# 1            5ème circonscription              01004
# 2            5ème circonscription              01007
# 3            4ème circonscription              01025
# 4            3ème circonscription              01033
# ..                            ...                ...
# 495          3ème circonscription              24129
# 496          2ème circonscription              24140
# 497          4ème circonscription              24142
# 498          5ème circonscription              21420
# 499          4ème circonscription              21434
#
#          Libellé de la commune Code du b.vote  Inscrits  Abstentions  \
# 0            Ambérieu-en-Bugey              1      1130          322
# 1            Ambérieu-en-Bugey              8      1129          250
# 2                     Ambronay              2       892          173
# 3               Bâgé-Dommartin              3       650          151
# 4                   Valserhône              2      1031          392
# ..                         ...            ...       ...          ...
# 495         Condat-sur-Trincou              1       384           81
# 496              Cours-de-Pile              1      1108          214
# 497  Coux et Bigaroque-Mouzens              2       211           48
# 498                    Molinot              1       161           42
# 499          Montlay-en-Auxois              1       130           24
#
#      % Abs/Ins  Votants  % Vot/Ins  Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  \
# 0        28.50      808      71.50      71          6.28          8.79    22
# 1        22.14      879      77.86      57          5.05          6.48    15
# 2        19.39      719      80.61      42          4.71          5.84    13
# 3        23.23      499      76.77      31          4.77          6.21     9
# 4        38.02      639      61.98      52          5.04          8.14    18
# ..         ...      ...        ...     ...           ...           ...   ...
# 495      21.09      303      78.91      16          4.17          5.28     6
# 496      19.31      894      80.69      71          6.41          7.94    29
# 497      22.75      163      77.25      10          4.74          6.13     4
# 498      26.09      119      73.91      13          8.07         10.92     6
# 499      18.46      106      81.54       8          6.15          7.55     5
#
#      % Nuls/Ins  % Nuls/Vot  Exprimés  % Exp/Ins  % Exp/Vot  N°Panneau Sexe  \
# 0          1.95        2.72       715      63.27      88.49          2    F
# 1          1.33        1.71       807      71.48      91.81          1    M
# 2          1.46        1.81       664      74.44      92.35          2    F
# 3          1.38        1.80       459      70.62      91.98          1    M
# 4          1.75        2.82       569      55.19      89.05          2    F
# ..          ...         ...       ...        ...        ...        ...  ...
# 495        1.56        1.98       281      73.18      92.74          1    M
# 496        2.62        3.24       794      71.66      88.81          2    F
# 497        1.90        2.45       149      70.62      91.41          1    M
# 498        3.73        5.04       100      62.11      84.03          2    F
# 499        3.85        4.72        93      71.54      87.74          2    F
#
#         Nom    Prénom  Voix  % Voix/Ins % Voix/Exp  Code Officiel EPCI  \
# 0    LE PEN    Marine   355       31.42      49,65         240100883.0
# 1    MACRON  Emmanuel   429       38.00      53,16         240100883.0
# 2    LE PEN    Marine   381       42.71      57,38         240100883.0
# 3    MACRON  Emmanuel   227       34.92      49,46         200071371.0
# 4    LE PEN    Marine   276       26.77      48,51         240100891.0
# ..      ...       ...   ...         ...        ...                 ...
# 495  MACRON  Emmanuel   109       28.39      38,79         200041572.0
# 496  LE PEN    Marine   436       39.35      54,91         200070647.0
# 497  MACRON  Emmanuel    94       44.55      63,09         200041051.0
# 498  LE PEN    Marine    53       32.92      53,00         200006682.0
# 499  LE PEN    Marine    54       41.54      58,06         200071017.0
#
#                                      Nom Officiel EPCI  Code Officiel Région  \
# 0                             CC de la Plaine de l'Ain                  84.0
# 1                             CC de la Plaine de l'Ain                  84.0
# 2                             CC de la Plaine de l'Ain                  84.0
# 3                                   CC Bresse et Saône                  84.0
# 4                       CC du Pays Bellegardien (CCPB)                  84.0
# ..                                                 ...                   ...
# 495                                 CC Dronne et Belle                  75.0
# 496                                    CA Bergeracoise                  75.0
# 497          CC Vallée de la Dordogne et Forêt Bessède                  75.0
# 498  CA Beaune,Côte et Sud - Communauté Beaune-Chag...                  27.0
# 499                             CC des Terres d'Auxois                  27.0
#
#          Nom Officiel Région scrutin_code             location  \
# 0       Auvergne-Rhône-Alpes       PR2022   45.959083, 5.36516
# 1       Auvergne-Rhône-Alpes       PR2022   45.959083, 5.36516
# 2       Auvergne-Rhône-Alpes       PR2022  46.011473, 5.362792
# 3       Auvergne-Rhône-Alpes       PR2022  46.337596, 4.989068
# 4       Auvergne-Rhône-Alpes       PR2022  46.128346, 5.809133
# ..                       ...          ...                  ...
# 495       Nouvelle-Aquitaine       PR2022  45.366064, 0.722254
# 496       Nouvelle-Aquitaine       PR2022  44.835202, 0.548552
# 497       Nouvelle-Aquitaine       PR2022  44.852649, 0.966584
# 498  Bourgogne-Franche-Comté       PR2022  47.011835, 4.584414
# 499  Bourgogne-Franche-Comté       PR2022  47.352345, 4.281476
#
#                     lib_du_b_vote
# 0                  B1 ESPACE 1500
# 1    B8 ECOLE MATERNELLE DE TIRET
# 2               SALLE POLYVALENTE
# 3                EX N 1 DOMMARTIN
# 4             CENTRE JEAN MARINET
# ..                            ...
# 495           BUREAU DE VOTE 0001
# 496            BUREAU N 01 MAIRIE
# 497        BUREAU DE VOTE MOUZENS
# 498             BUREAU 01 MOLINOT
# 499                             1
#
# [500 rows x 35 columns]

# %%
df['% Voix/Exp'] = df['% Voix/Exp'].astype('string')
df['% Voix/Exp'] = df['% Voix/Exp'].replace(',', '.',regex = True)
df.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  01                    Ain                           5
# 1                  01                    Ain                           5
# 2                  01                    Ain                           5
# 3                  01                    Ain                           4
# 4                  01                    Ain                           3
#
#   Libellé de la circonscription Code de la commune Libellé de la commune  \
# 0          5ème circonscription              01004     Ambérieu-en-Bugey
# 1          5ème circonscription              01004     Ambérieu-en-Bugey
# 2          5ème circonscription              01007              Ambronay
# 3          4ème circonscription              01025        Bâgé-Dommartin
# 4          3ème circonscription              01033            Valserhône
#
#   Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0              1      1130          322      28.50      808      71.50
# 1              8      1129          250      22.14      879      77.86
# 2              2       892          173      19.39      719      80.61
# 3              3       650          151      23.23      499      76.77
# 4              2      1031          392      38.02      639      61.98
#
#    Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  Exprimés  \
# 0      71          6.28          8.79    22        1.95        2.72       715
# 1      57          5.05          6.48    15        1.33        1.71       807
# 2      42          4.71          5.84    13        1.46        1.81       664
# 3      31          4.77          6.21     9        1.38        1.80       459
# 4      52          5.04          8.14    18        1.75        2.82       569
#
#    % Exp/Ins  % Exp/Vot  N°Panneau Sexe     Nom    Prénom  Voix  % Voix/Ins  \
# 0      63.27      88.49          2    F  LE PEN    Marine   355       31.42
# 1      71.48      91.81          1    M  MACRON  Emmanuel   429       38.00
# 2      74.44      92.35          2    F  LE PEN    Marine   381       42.71
# 3      70.62      91.98          1    M  MACRON  Emmanuel   227       34.92
# 4      55.19      89.05          2    F  LE PEN    Marine   276       26.77
#
#   % Voix/Exp  Code Officiel EPCI               Nom Officiel EPCI  \
# 0      49.65         240100883.0        CC de la Plaine de l'Ain
# 1      53.16         240100883.0        CC de la Plaine de l'Ain
# 2      57.38         240100883.0        CC de la Plaine de l'Ain
# 3      49.46         200071371.0              CC Bresse et Saône
# 4      48.51         240100891.0  CC du Pays Bellegardien (CCPB)
#
#    Code Officiel Région   Nom Officiel Région scrutin_code  \
# 0                  84.0  Auvergne-Rhône-Alpes       PR2022
# 1                  84.0  Auvergne-Rhône-Alpes       PR2022
# 2                  84.0  Auvergne-Rhône-Alpes       PR2022
# 3                  84.0  Auvergne-Rhône-Alpes       PR2022
# 4                  84.0  Auvergne-Rhône-Alpes       PR2022
#
#               location                 lib_du_b_vote
# 0   45.959083, 5.36516                B1 ESPACE 1500
# 1   45.959083, 5.36516  B8 ECOLE MATERNELLE DE TIRET
# 2  46.011473, 5.362792             SALLE POLYVALENTE
# 3  46.337596, 4.989068              EX N 1 DOMMARTIN
# 4  46.128346, 5.809133           CENTRE JEAN MARINET

# %%
df.describe(include = 'all')
# Out:
#        Code du département Libellé du département  Code de la circonscription  \
# count               139396                 139396               139396.000000
# unique                  97                    107                         NaN
# top                     97                   Nord                         NaN
# freq                  5578                   4004                         NaN
# mean                   NaN                    NaN                    4.185213
# std                    NaN                    NaN                    3.289314
# min                    NaN                    NaN                    1.000000
# 25%                    NaN                    NaN                    2.000000
# 50%                    NaN                    NaN                    3.000000
# 75%                    NaN                    NaN                    5.000000
# max                    NaN                    NaN                   21.000000
#
#        Libellé de la circonscription Code de la commune Libellé de la commune  \
# count                         139396             139396                139396
# unique                            22              35185                 32988
# top             2ème circonscription              75056                 Paris
# freq                           26922               1800                  1800
# mean                             NaN                NaN                   NaN
# std                              NaN                NaN                   NaN
# min                              NaN                NaN                   NaN
# 25%                              NaN                NaN                   NaN
# 50%                              NaN                NaN                   NaN
# 75%                              NaN                NaN                   NaN
# max                              NaN                NaN                   NaN
#
#        Code du b.vote       Inscrits    Abstentions      % Abs/Ins  \
# count          139396  139396.000000  139396.000000  139396.000000
# unique           1748            NaN            NaN            NaN
# top                 1            NaN            NaN            NaN
# freq            70412            NaN            NaN            NaN
# mean              NaN     699.583202     195.960501      25.492756
# std               NaN     974.472585     548.846889       9.939021
# min               NaN       0.000000       0.000000       0.000000
# 25%               NaN     298.000000      62.000000      19.620000
# 50%               NaN     753.000000     180.000000      23.300000
# 75%               NaN     972.000000     267.000000      28.670000
# max               NaN  123838.000000   67811.000000     100.000000
#
#               Votants      % Vot/Ins         Blancs   % Blancs/Ins  \
# count   139396.000000  139396.000000  139396.000000  139396.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean       503.622701      74.491491      32.056329       4.998044
# std        473.538943       9.977854      22.555089       2.342915
# min          0.000000       0.000000       0.000000       0.000000
# 25%        230.000000      71.330000      15.000000       3.660000
# 50%        531.000000      76.690000      31.000000       4.720000
# 75%        710.000000      80.380000      46.000000       5.960000
# max      56027.000000     100.000000    1723.000000      54.170000
#
#          % Blancs/Vot           Nuls     % Nuls/Ins     % Nuls/Vot  \
# count   139396.000000  139396.000000  139396.000000  139396.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         6.680492      11.555654       1.865825       2.516737
# std          3.003521      16.962263       2.373733       3.144037
# min          0.000000       0.000000       0.000000       0.000000
# 25%          5.030000       5.000000       1.050000       1.430000
# 50%          6.360000      10.000000       1.570000       2.120000
# 75%          7.880000      16.000000       2.270000       3.040000
# max        100.000000    1156.000000     100.000000     100.000000
#
#              Exprimés      % Exp/Ins      % Exp/Vot      N°Panneau    Sexe  \
# count   139396.000000  139396.000000  139396.000000  139396.000000  139396
# unique            NaN            NaN            NaN            NaN       2
# top               NaN            NaN            NaN            NaN       F
# freq              NaN            NaN            NaN            NaN   69698
# mean       460.010718      67.627647      90.736853       1.500000     NaN
# std        450.818964       9.536066       4.891922       0.500002     NaN
# min          0.000000       0.000000       0.000000       1.000000     NaN
# 25%        207.000000      64.270000      89.420000       1.000000     NaN
# 50%        483.000000      69.470000      91.370000       1.500000     NaN
# 75%        649.000000      73.310000      92.970000       2.000000     NaN
# max      53973.000000     100.000000     100.000000       2.000000     NaN
#
#            Nom  Prénom           Voix     % Voix/Ins % Voix/Exp  \
# count   139396  139396  139396.000000  139396.000000     139396
# unique       2       2            NaN            NaN       8069
# top     LE PEN  Marine            NaN            NaN      50.00
# freq     69698   69698            NaN            NaN        952
# mean       NaN     NaN     230.005359      33.813796        NaN
# std        NaN     NaN     279.332785      11.127905        NaN
# min        NaN     NaN       0.000000       0.000000        NaN
# 25%        NaN     NaN      97.000000      26.710000        NaN
# 50%        NaN     NaN     202.000000      33.960000        NaN
# 75%        NaN     NaN     322.000000      40.940000        NaN
# max        NaN     NaN   43866.000000     100.000000        NaN
#
#         Code Officiel EPCI         Nom Officiel EPCI  Code Officiel Région  \
# count         1.379240e+05                    137924         137998.000000
# unique                 NaN                      1251                   NaN
# top                    NaN  Métropole du Grand Paris                   NaN
# freq                   NaN                      7370                   NaN
# mean          2.149617e+08                       NaN             50.802157
# std           2.123337e+07                       NaN             33.742554
# min           2.000002e+08                       NaN              1.000000
# 25%           2.000548e+08                       NaN             28.000000
# 50%           2.000696e+08                       NaN             44.000000
# 75%           2.431005e+08                       NaN             76.000000
# max           2.497401e+08                       NaN            978.000000
#
#        Nom Officiel Région scrutin_code              location lib_du_b_vote
# count               137998       139396                131980        132888
# unique                  21            1                 42335         29543
# top              Grand Est       PR2022  44.851895, -0.587877        MAIRIE
# freq                 15272       139396                   296         21070
# mean                   NaN          NaN                   NaN           NaN
# std                    NaN          NaN                   NaN           NaN
# min                    NaN          NaN                   NaN           NaN
# 25%                    NaN          NaN                   NaN           NaN
# 50%                    NaN          NaN                   NaN           NaN
# 75%                    NaN          NaN                   NaN           NaN
# max                    NaN          NaN                   NaN           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139396 entries, 0 to 139395
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Code du département            139396 non-null  object
#  1   Libellé du département         139396 non-null  object
#  2   Code de la circonscription     139396 non-null  int64
#  3   Libellé de la circonscription  139396 non-null  object
#  4   Code de la commune             139396 non-null  object
#  5   Libellé de la commune          139396 non-null  object
#  6   Code du b.vote                 139396 non-null  object
#  7   Inscrits                       139396 non-null  int64
#  8   Abstentions                    139396 non-null  int64
#  9   % Abs/Ins                      139396 non-null  float64
#  10  Votants                        139396 non-null  int64
#  11  % Vot/Ins                      139396 non-null  float64
#  12  Blancs                         139396 non-null  int64
#  13  % Blancs/Ins                   139396 non-null  float64
#  14  % Blancs/Vot                   139396 non-null  float64
#  15  Nuls                           139396 non-null  int64
#  16  % Nuls/Ins                     139396 non-null  float64
#  17  % Nuls/Vot                     139396 non-null  float64
#  18  Exprimés                       139396 non-null  int64
#  19  % Exp/Ins                      139396 non-null  float64
#  20  % Exp/Vot                      139396 non-null  float64
#  21  N°Panneau                      139396 non-null  int64
#  22  Sexe                           139396 non-null  object
#  23  Nom                            139396 non-null  object
#  24  Prénom                         139396 non-null  object
#  25  Voix                           139396 non-null  int64
#  26  % Voix/Ins                     139396 non-null  float64
#  27  % Voix/Exp                     139396 non-null  string
#  28  Code Officiel EPCI             137924 non-null  float64
#  29  Nom Officiel EPCI              137924 non-null  object
#  30  Code Officiel Région           137998 non-null  float64
#  31  Nom Officiel Région            137998 non-null  object
#  32  scrutin_code                   139396 non-null  object
#  33  location                       131980 non-null  object
#  34  lib_du_b_vote                  132888 non-null  object
# dtypes: float64(11), int64(9), object(14), string(1)
# memory usage: 37.2+ MB

# %%
df_separato = df['location'].str.split(',', expand=True)
df_separato.columns = ['Latitudine', 'Longitudine']
df_separato.head()
# Out:
#   Latitudine Longitudine
# 0  45.959083     5.36516
# 1  45.959083     5.36516
# 2  46.011473    5.362792
# 3  46.337596    4.989068
# 4  46.128346    5.809133

# %%
df = pd.concat([df, df_separato], axis=1)
df = df.drop('location',axis = 1)
df.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  01                    Ain                           5
# 1                  01                    Ain                           5
# 2                  01                    Ain                           5
# 3                  01                    Ain                           4
# 4                  01                    Ain                           3
#
#   Libellé de la circonscription Code de la commune Libellé de la commune  \
# 0          5ème circonscription              01004     Ambérieu-en-Bugey
# 1          5ème circonscription              01004     Ambérieu-en-Bugey
# 2          5ème circonscription              01007              Ambronay
# 3          4ème circonscription              01025        Bâgé-Dommartin
# 4          3ème circonscription              01033            Valserhône
#
#   Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0              1      1130          322      28.50      808      71.50
# 1              8      1129          250      22.14      879      77.86
# 2              2       892          173      19.39      719      80.61
# 3              3       650          151      23.23      499      76.77
# 4              2      1031          392      38.02      639      61.98
#
#    Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  Exprimés  \
# 0      71          6.28          8.79    22        1.95        2.72       715
# 1      57          5.05          6.48    15        1.33        1.71       807
# 2      42          4.71          5.84    13        1.46        1.81       664
# 3      31          4.77          6.21     9        1.38        1.80       459
# 4      52          5.04          8.14    18        1.75        2.82       569
#
#    % Exp/Ins  % Exp/Vot  N°Panneau Sexe     Nom    Prénom  Voix  % Voix/Ins  \
# 0      63.27      88.49          2    F  LE PEN    Marine   355       31.42
# 1      71.48      91.81          1    M  MACRON  Emmanuel   429       38.00
# 2      74.44      92.35          2    F  LE PEN    Marine   381       42.71
# 3      70.62      91.98          1    M  MACRON  Emmanuel   227       34.92
# 4      55.19      89.05          2    F  LE PEN    Marine   276       26.77
#
#   % Voix/Exp  Code Officiel EPCI               Nom Officiel EPCI  \
# 0      49.65         240100883.0        CC de la Plaine de l'Ain
# 1      53.16         240100883.0        CC de la Plaine de l'Ain
# 2      57.38         240100883.0        CC de la Plaine de l'Ain
# 3      49.46         200071371.0              CC Bresse et Saône
# 4      48.51         240100891.0  CC du Pays Bellegardien (CCPB)
#
#    Code Officiel Région   Nom Officiel Région scrutin_code  \
# 0                  84.0  Auvergne-Rhône-Alpes       PR2022
# 1                  84.0  Auvergne-Rhône-Alpes       PR2022
# 2                  84.0  Auvergne-Rhône-Alpes       PR2022
# 3                  84.0  Auvergne-Rhône-Alpes       PR2022
# 4                  84.0  Auvergne-Rhône-Alpes       PR2022
#
#                   lib_du_b_vote Latitudine Longitudine
# 0                B1 ESPACE 1500  45.959083     5.36516
# 1  B8 ECOLE MATERNELLE DE TIRET  45.959083     5.36516
# 2             SALLE POLYVALENTE  46.011473    5.362792
# 3              EX N 1 DOMMARTIN  46.337596    4.989068
# 4           CENTRE JEAN MARINET  46.128346    5.809133

# %%
duplicati_presenti = df.duplicated().any()

if duplicati_presenti:
    print("Sono presenti duplicati nel DataFrame.")
else:
    print("Non ci sono duplicati nel DataFrame.")
# Out:
# Non ci sono duplicati nel DataFrame.

# %% [markdown]
# ## 1.2.Gestione dei valori nulli

# %%
#Rimuovo le righe con il nome della regione nullo
df = df.dropna(subset=['Nom Officiel Région'])

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Code du département  Libellé du département  Code de la circonscription  \
# 0                False                   False                       False
# 1                False                   False                       False
# 2                False                   False                       False
# 3                False                   False                       False
# 4                False                   False                       False
#
#    Libellé de la circonscription  Code de la commune  Libellé de la commune  \
# 0                          False               False                  False
# 1                          False               False                  False
# 2                          False               False                  False
# 3                          False               False                  False
# 4                          False               False                  False
#
#    Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0           False     False        False      False    False      False
# 1           False     False        False      False    False      False
# 2           False     False        False      False    False      False
# 3           False     False        False      False    False      False
# 4           False     False        False      False    False      False
#
#    Blancs  % Blancs/Ins  % Blancs/Vot   Nuls  % Nuls/Ins  % Nuls/Vot  \
# 0   False         False         False  False       False       False
# 1   False         False         False  False       False       False
# 2   False         False         False  False       False       False
# 3   False         False         False  False       False       False
# 4   False         False         False  False       False       False
#
#    Exprimés  % Exp/Ins  % Exp/Vot  N°Panneau   Sexe    Nom  Prénom   Voix  \
# 0     False      False      False      False  False  False   False  False
# 1     False      False      False      False  False  False   False  False
# 2     False      False      False      False  False  False   False  False
# 3     False      False      False      False  False  False   False  False
# 4     False      False      False      False  False  False   False  False
#
#    % Voix/Ins  % Voix/Exp  Code Officiel EPCI  Nom Officiel EPCI  \
# 0       False       False               False              False
# 1       False       False               False              False
# 2       False       False               False              False
# 3       False       False               False              False
# 4       False       False               False              False
#
#    Code Officiel Région  Nom Officiel Région  scrutin_code  lib_du_b_vote  \
# 0                 False                False         False          False
# 1                 False                False         False          False
# 2                 False                False         False          False
# 3                 False                False         False          False
# 4                 False                False         False          False
#
#    Latitudine  Longitudine
# 0       False        False
# 1       False        False
# 2       False        False
# 3       False        False
# 4       False        False

# %%
for column in missing_data.columns.values.tolist():
    print (missing_data[column].value_counts())
    print("")
# Out:
# False    137998
# Name: Code du département, dtype: int64
#
# False    137998
# Name: Libellé du département, dtype: int64
#
# False    137998
# Name: Code de la circonscription, dtype: int64
#
# False    137998
# Name: Libellé de la circonscription, dtype: int64
#
# False    137998
# Name: Code de la commune, dtype: int64
#
# False    137998
# Name: Libellé de la commune, dtype: int64
#
# False    137998
# Name: Code du b.vote, dtype: int64
#
# False    137998
# Name: Inscrits, dtype: int64
#
# False    137998
# Name: Abstentions, dtype: int64
#
# False    137998
# Name: % Abs/Ins, dtype: int64
#
# False    137998
# Name: Votants, dtype: int64
#
# False    137998
# Name: % Vot/Ins, dtype: int64
#
# False    137998
# Name: Blancs, dtype: int64
#
# False    137998
# Name: % Blancs/Ins, dtype: int64
#
# False    137998
# Name: % Blancs/Vot, dtype: int64
#
# False    137998
# Name: Nuls, dtype: int64
#
# False    137998
# Name: % Nuls/Ins, dtype: int64
#
# False    137998
# Name: % Nuls/Vot, dtype: int64
#
# False    137998
# Name: Exprimés, dtype: int64
#
# False    137998
# Name: % Exp/Ins, dtype: int64
#
# False    137998
# Name: % Exp/Vot, dtype: int64
#
# False    137998
# Name: N°Panneau, dtype: int64
#
# False    137998
# Name: Sexe, dtype: int64
#
# False    137998
# Name: Nom, dtype: int64
#
# False    137998
# Name: Prénom, dtype: int64
#
# False    137998
# Name: Voix, dtype: int64
#
# False    137998
# Name: % Voix/Ins, dtype: int64
#
# False    137998
# Name: % Voix/Exp, dtype: int64
#
# False    137924
# True         74
# Name: Code Officiel EPCI, dtype: int64
#
# False    137924
# True         74
# Name: Nom Officiel EPCI, dtype: int64
#
# False    137998
# Name: Code Officiel Région, dtype: int64
#
# False    137998
# Name: Nom Officiel Région, dtype: int64
#
# False    137998
# Name: scrutin_code, dtype: int64
#
# False    132888
# True       5110
# Name: lib_du_b_vote, dtype: int64
#
# False    131980
# True       6018
# Name: Latitudine, dtype: int64
#
# False    131980
# True       6018
# Name: Longitudine, dtype: int64

# %%
df = df.drop('lib_du_b_vote',axis = 1)

# %% [markdown]
# ## 1.3.Gestione dei tipi

# %%
df.dtypes
# Out:
# Code du département               object
# Libellé du département            object
# Code de la circonscription         int64
# Libellé de la circonscription     object
# Code de la commune                object
# Libellé de la commune             object
# Code du b.vote                    object
# Inscrits                           int64
# Abstentions                        int64
# % Abs/Ins                        float64
# Votants                            int64
# % Vot/Ins                        float64
# Blancs                             int64
# % Blancs/Ins                     float64
# % Blancs/Vot                     float64
# Nuls                               int64
# % Nuls/Ins                       float64
# % Nuls/Vot                       float64
# Exprimés                           int64
# % Exp/Ins                        float64
# % Exp/Vot                        float64
# N°Panneau                          int64
# Sexe                              object
# Nom                               object
# Prénom                            object
# Voix                               int64
# % Voix/Ins                       float64
# % Voix/Exp                        string
# Code Officiel EPCI               float64
# Nom Officiel EPCI                 object
# Code Officiel Région             float64
# Nom Officiel Région               object
# scrutin_code                      object
# Latitudine                        object
# Longitudine                       object
# dtype: object

# %%
df[['Code du département','Code de la commune', 'Code du b.vote']] = df[['Code du département','Code de la commune', 'Code du b.vote']].astype("string")
df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune',
    'Sexe','Nom','Prénom','Nom Officiel Région','scrutin_code']] = df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune',
                                                        'Sexe','Nom','Prénom','Nom Officiel Région','scrutin_code']].astype("string")
df[['Latitudine','Longitudine','% Voix/Exp']] = df[['Latitudine','Longitudine','% Voix/Exp']].astype('float')

# %%
df.dtypes
# Out:
# Code du département               string
# Libellé du département            string
# Code de la circonscription         int64
# Libellé de la circonscription     string
# Code de la commune                string
# Libellé de la commune             string
# Code du b.vote                    string
# Inscrits                           int64
# Abstentions                        int64
# % Abs/Ins                        float64
# Votants                            int64
# % Vot/Ins                        float64
# Blancs                             int64
# % Blancs/Ins                     float64
# % Blancs/Vot                     float64
# Nuls                               int64
# % Nuls/Ins                       float64
# % Nuls/Vot                       float64
# Exprimés                           int64
# % Exp/Ins                        float64
# % Exp/Vot                        float64
# N°Panneau                          int64
# Sexe                              string
# Nom                               string
# Prénom                            string
# Voix                               int64
# % Voix/Ins                       float64
# % Voix/Exp                       float64
# Code Officiel EPCI               float64
# Nom Officiel EPCI                 object
# Code Officiel Région             float64
# Nom Officiel Région               string
# scrutin_code                      string
# Latitudine                       float64
# Longitudine                      float64
# dtype: object

# %% [markdown]
# ## 1.4 Eliminazione dei dipartimenti del gruppo 1

# %%
df.shape
# Out:
# (137998, 35)

# %%
df = df.drop(df[df['Nom Officiel Région'] == 'Hauts-de-France'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Grand Est'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Île-de-France'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Normandie'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Bretagne'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Bourgogne-Franche-Comté'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Centre-Val de Loire'].index)

# %%
lista_nome_regioni = df['Nom Officiel Région'].unique()
print(lista_nome_regioni)
print(df.shape)
# Out:
# <StringArray>
# [      'Auvergne-Rhône-Alpes', "Provence-Alpes-Côte d'Azur",
#          'Nouvelle-Aquitaine',                      'Corse',
#                   'Occitanie',           'Pays de la Loire',
#                  'Guadeloupe',                 'Martinique',
#                      'Guyane',                 'La Réunion',
#                     'Mayotte',           'Saint-Barthélemy',
#    'Saint-Pierre-et-Miquelon',               'Saint-Martin']
# Length: 14, dtype: string
# (64850, 35)

# %% [markdown]
# ## 1.6.Salvataggio del dataSet pulito

# %%
path = '/content/drive/Shareddrives/Progetto Big Data/DataSet Puliti/presidentielles-2022-2nd-tour_cleaned.csv'
df.to_csv(path,index=False, sep = ';');
