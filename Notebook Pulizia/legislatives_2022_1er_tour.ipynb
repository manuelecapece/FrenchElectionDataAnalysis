# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelecapece/Unibas-Progetto-Big-data-2022-23/blob/main/legislatives_2022_1er_tour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # **1.Data Preparation**

# %%
path = '/content/drive/Shareddrives/Progetto Big Data/DataSet/elections-france-legislatives-2022-1er-tour-par-bureau-de-vote.csv'
df = pd.read_csv(path, sep = ';')
# Out:
# <ipython-input-2-034b44181e44>:2: DtypeWarning: Columns (0,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep = ';')

# %% [markdown]
# ## 1.1.Comprensione del dataSet

# %%
df.tail(
  
)
# Out:
#        Code du département Libellé du département  Code de la circonscription  \
# 740382                  82        Tarn-et-Garonne                           1
# 740383                  82        Tarn-et-Garonne                           2
# 740384                  82        Tarn-et-Garonne                           2
# 740385                  82        Tarn-et-Garonne                           1
# 740386                  82        Tarn-et-Garonne                           2
#
#        Libellé de la circonscription Code de la commune  \
# 740382          1ère circonscription              82174
# 740383          2ème circonscription              82175
# 740384          2ème circonscription              82178
# 740385          1ère circonscription              82179
# 740386          2ème circonscription              82181
#
#            Libellé de la commune Code du b.vote  Inscrits  Abstentions  \
# 740382   Saint-Vincent-d'Autéjac              1       232           81
# ...

# %%
df.describe(include='all')

# %%
df.info()

# %% [markdown]
# ## 1.2.Gestione dei valori nulli

# %% [markdown]
# ## 1.3.Gestione dei tipi

# %%
df.dtypes
# Out:
# Code du département               string
# Libellé du département            string
# Code de la circonscription         int64
# Libellé de la circonscription     string
# Code de la commune                string
# Libellé de la commune             string
# Code du b.vote                    string
# Inscrits                           int64
# Abstentions                        int64
# % Abs/Ins                        float64
# Votants                            int64
# % Vot/Ins                        float64
# Blancs                             int64
# % Blancs/Ins                     float64
# % Blancs/Vot                     float64
# Nuls                               int64
# % Nuls/Ins                       float64
# % Nuls/Vot                       float64
# Exprimés                           int64
# % Exp/Ins                        float64
# % Exp/Vot                        float64
# N°Panneau                          int64
# Sexe                              string
# ...

# %%
df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune', 'Sexe', 'Nom' ,
    'Prénom', 'Nuance','Nom Officiel EPCI','Nom Officiel Région','lib_du_b_vote','scrutin_code','Code du département','Code de la commune' ,'Code du b.vote','% Voix/Exp']] = df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune', 'Sexe', 'Nom' ,
    'Prénom', 'Nuance','Nom Officiel EPCI','Nom Officiel Région','lib_du_b_vote','scrutin_code','Code du département','Code de la commune','Code du b.vote','% Voix/Exp' ]].astype("string")

df['% Voix/Exp'] = df['% Voix/Exp'].str.replace(",",".")
df[['% Voix/Exp']] = df[['% Voix/Exp' ]].astype("float64")
