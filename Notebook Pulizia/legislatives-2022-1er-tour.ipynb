# %%
import pandas as pd
import numpy as np
from google.colab.data_table import DataTable
from google.colab import drive
from google.colab import files

# %%
drive.mount('/content/drive')
pd.set_option('display.max_columns', None)
DataTable.max_columns = 99
# Out:
# Mounted at /content/drive

# %% [markdown]
# ```
# # Questo è formattato come codice
# ```
#
# # **1.Data Preparation**

# %%
path = '/content/drive/Shareddrives/Progetto Big Data/DataSet/elections-france-legislatives-2022-1er-tour-par-bureau-de-vote.csv'
df = pd.read_csv(path, sep = ';')
# Out:
# <ipython-input-3-034b44181e44>:2: DtypeWarning: Columns (0,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep = ';')

# %% [markdown]
# ## 1.1.Comprensione del dataSet e sistemazione delle colonne

# %%
df.head(500)
# Out:
#     Code du département Libellé du département  Code de la circonscription  \
# 0                    13       Bouches-du-Rhône                          12
# 1                    13       Bouches-du-Rhône                          12
# 2                    13       Bouches-du-Rhône                          12
# 3                    13       Bouches-du-Rhône                          12
# 4                    13       Bouches-du-Rhône                          12
# ..                  ...                    ...                         ...
# 495                  11                   Aude                           3
# 496                  11                   Aude                           2
# 497                  11                   Aude                           2
# 498                  11                   Aude                           3
# 499                  11                   Aude                           3
#
#     Libellé de la circonscription Code de la commune Libellé de la commune  \
# 0           12ème circonscription              13054             Marignane
# 1           12ème circonscription              13054             Marignane
# 2           12ème circonscription              13054             Marignane
# 3           12ème circonscription              13054             Marignane
# 4           12ème circonscription              13054             Marignane
# ..                            ...                ...                   ...
# 495          3ème circonscription              11304               Quillan
# 496          2ème circonscription              11307        Raissac-d'Aude
# 497          2ème circonscription              11307        Raissac-d'Aude
# 498          3ème circonscription              11311               Ribaute
# 499          3ème circonscription              11313                Ricaud
#
#     Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0               17       935          547      58.50      388      41.50
# 1               19       862          448      51.97      414      48.03
# 2               20       984          648      65.85      336      34.15
# 3               21       604          372      61.59      232      38.41
# 4               23       980          652      66.53      328      33.47
# ..             ...       ...          ...        ...      ...        ...
# 495              3       603          296      49.09      307      50.91
# 496              1       202           91      45.05      111      54.95
# 497              1       202           91      45.05      111      54.95
# 498              1       219          101      46.12      118      53.88
# 499              1       257           96      37.35      161      62.65
#
#      Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  \
# 0         7          0.75          1.80     0        0.00        0.00
# 1        11          1.28          2.66     0        0.00        0.00
# 2        12          1.22          3.57     0        0.00        0.00
# 3         2          0.33          0.86     0        0.00        0.00
# 4         7          0.71          2.13     0        0.00        0.00
# ..      ...           ...           ...   ...         ...         ...
# 495      10          1.66          3.26     7        1.16        2.28
# 496       6          2.97          5.41     0        0.00        0.00
# 497       6          2.97          5.41     0        0.00        0.00
# 498       2          0.91          1.69     2        0.91        1.69
# 499       4          1.56          2.48     1        0.39        0.62
#
#      Exprimés  % Exp/Ins  % Exp/Vot  N°Panneau Sexe           Nom    Prénom  \
# 0         381      40.75      98.20          8    M       RIBEIRO  Stéphane
# 1         403      46.75      97.34          3    M     DELESPAUL     Hervé
# 2         324      32.93      96.43          3    M     DELESPAUL     Hervé
# 3         230      38.08      99.14          5    M         ROCHE  François
# 4         321      32.76      97.87          8    M       RIBEIRO  Stéphane
# ..        ...        ...        ...        ...  ...           ...       ...
# 495       290      48.09      94.46          6    M        MARTIN    Michel
# 496       105      51.98      94.59         10    F        VIGIER   Annette
# 497       105      51.98      94.59          5    M       LENFANT    Gérard
# 498       114      52.05      96.61          8    F  ADDA--NETTER   Johanna
# 499       156      60.70      96.89          3    M      RANCOULE    Julien
#
#     Nuance  Voix  % Voix/Ins % Voix/Exp  Code Officiel EPCI  \
# 0      ECO     2        0.21       0,52         200054807.0
# 1      DSV     8        0.93       1,99         200054807.0
# 2      DSV     4        0.41       1,23         200054807.0
# 3      DXG     1        0.17       0,43         200054807.0
# 4      ECO     4        0.41       1,25         200054807.0
# ..     ...   ...         ...        ...                 ...
# 495    DXG     2        0.33       0,69         200043776.0
# 496    DXG     2        0.99       1,90         241100593.0
# 497    DIV     4        1.98       3,81         241100593.0
# 498    NUP    48       21.92      42,11         200035863.0
# 499     RN    40       15.56      25,64         200035855.0
#
#                                  Nom Officiel EPCI  Code Officiel Région  \
# 0               Métropole d'Aix-Marseille-Provence                  93.0
# 1               Métropole d'Aix-Marseille-Provence                  93.0
# 2               Métropole d'Aix-Marseille-Provence                  93.0
# 3               Métropole d'Aix-Marseille-Provence                  93.0
# 4               Métropole d'Aix-Marseille-Provence                  93.0
# ..                                             ...                   ...
# 495                           CC Pyrénées Audoises                  76.0
# 496                           CA Le Grand Narbonne                  76.0
# 497                           CA Le Grand Narbonne                  76.0
# 498  CC Région Lézignanaise,Corbières et Minervois                  76.0
# 499              CC Castelnaudary Lauragais Audois                  76.0
#
#             Nom Officiel Région             location  \
# 0    Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 1    Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 2    Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 3    Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 4    Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# ..                          ...                  ...
# 495                   Occitanie  42.894497, 2.166324
# 496                   Occitanie  43.229248, 2.876178
# 497                   Occitanie  43.229248, 2.876178
# 498                   Occitanie  43.107768, 2.633152
# 499                   Occitanie   43.346907, 1.88942
#
#                           lib_du_b_vote scrutin_code
# 0             PARC DES SPORTS DU BOLMON       LG2022
# 1      CENTRE SOCIO CULT J RAIMU LE JAI       LG2022
# 2                  GYMNASE DU CARESTIER       LG2022
# 3                  GYMNASE DU CARESTIER       LG2022
# 4             PARC DES SPORTS DU BOLMON       LG2022
# ..                                  ...          ...
# 495                 3EME BUREAU DE VOTE       LG2022
# 496                              MAIRIE       LG2022
# 497                              MAIRIE       LG2022
# 498                              MAIRIE       LG2022
# 499  3EME CIRCONSCRIPTION BUREAU UNIQUE       LG2022
#
# [500 rows x 36 columns]

# %%
df['% Voix/Exp'] = df['% Voix/Exp'].astype('string')
df['% Voix/Exp'] = df['% Voix/Exp'].replace(',', '.',regex = True)
df.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  13       Bouches-du-Rhône                          12
# 1                  13       Bouches-du-Rhône                          12
# 2                  13       Bouches-du-Rhône                          12
# 3                  13       Bouches-du-Rhône                          12
# 4                  13       Bouches-du-Rhône                          12
#
#   Libellé de la circonscription Code de la commune Libellé de la commune  \
# 0         12ème circonscription              13054             Marignane
# 1         12ème circonscription              13054             Marignane
# 2         12ème circonscription              13054             Marignane
# 3         12ème circonscription              13054             Marignane
# 4         12ème circonscription              13054             Marignane
#
#   Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0             17       935          547      58.50      388      41.50
# 1             19       862          448      51.97      414      48.03
# 2             20       984          648      65.85      336      34.15
# 3             21       604          372      61.59      232      38.41
# 4             23       980          652      66.53      328      33.47
#
#    Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  Exprimés  \
# 0       7          0.75          1.80     0         0.0         0.0       381
# 1      11          1.28          2.66     0         0.0         0.0       403
# 2      12          1.22          3.57     0         0.0         0.0       324
# 3       2          0.33          0.86     0         0.0         0.0       230
# 4       7          0.71          2.13     0         0.0         0.0       321
#
#    % Exp/Ins  % Exp/Vot  N°Panneau Sexe        Nom    Prénom Nuance  Voix  \
# 0      40.75      98.20          8    M    RIBEIRO  Stéphane    ECO     2
# 1      46.75      97.34          3    M  DELESPAUL     Hervé    DSV     8
# 2      32.93      96.43          3    M  DELESPAUL     Hervé    DSV     4
# 3      38.08      99.14          5    M      ROCHE  François    DXG     1
# 4      32.76      97.87          8    M    RIBEIRO  Stéphane    ECO     4
#
#    % Voix/Ins % Voix/Exp  Code Officiel EPCI  \
# 0        0.21       0.52         200054807.0
# 1        0.93       1.99         200054807.0
# 2        0.41       1.23         200054807.0
# 3        0.17       0.43         200054807.0
# 4        0.41       1.25         200054807.0
#
#                     Nom Officiel EPCI  Code Officiel Région  \
# 0  Métropole d'Aix-Marseille-Provence                  93.0
# 1  Métropole d'Aix-Marseille-Provence                  93.0
# 2  Métropole d'Aix-Marseille-Provence                  93.0
# 3  Métropole d'Aix-Marseille-Provence                  93.0
# 4  Métropole d'Aix-Marseille-Provence                  93.0
#
#           Nom Officiel Région             location  \
# 0  Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 1  Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 2  Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 3  Provence-Alpes-Côte d'Azur  43.415837, 5.220936
# 4  Provence-Alpes-Côte d'Azur  43.415837, 5.220936
#
#                       lib_du_b_vote scrutin_code
# 0         PARC DES SPORTS DU BOLMON       LG2022
# 1  CENTRE SOCIO CULT J RAIMU LE JAI       LG2022
# 2              GYMNASE DU CARESTIER       LG2022
# 3              GYMNASE DU CARESTIER       LG2022
# 4         PARC DES SPORTS DU BOLMON       LG2022

# %%
df.describe(include = 'all')
# Out:
#        Code du département Libellé du département  Code de la circonscription  \
# count               740387                 740387               740387.000000
# unique                 191                    107                         NaN
# top                     97                   Nord                         NaN
# freq                 19679                  19092                         NaN
# mean                   NaN                    NaN                    4.244383
# std                    NaN                    NaN                    3.281989
# min                    NaN                    NaN                    1.000000
# 25%                    NaN                    NaN                    2.000000
# 50%                    NaN                    NaN                    3.000000
# 75%                    NaN                    NaN                    6.000000
# max                    NaN                    NaN                   21.000000
#
#        Libellé de la circonscription Code de la commune Libellé de la commune  \
# count                         740387             740387                740387
# unique                            22              68187                 32989
# top             2ème circonscription              75056                 Paris
# freq                          143663               7874                 10974
# mean                             NaN                NaN                   NaN
# std                              NaN                NaN                   NaN
# min                              NaN                NaN                   NaN
# 25%                              NaN                NaN                   NaN
# 50%                              NaN                NaN                   NaN
# 75%                              NaN                NaN                   NaN
# max                              NaN                NaN                   NaN
#
#        Code du b.vote       Inscrits    Abstentions      % Abs/Ins  \
# count          740387  740387.000000  740387.000000  740387.000000
# unique           3069            NaN            NaN            NaN
# top                 1            NaN            NaN            NaN
# freq           324717            NaN            NaN            NaN
# mean              NaN     725.588954     383.562796      49.935890
# std               NaN    1070.493536     802.383132      10.138142
# min               NaN       0.000000       0.000000       0.000000
# 25%               NaN     332.000000     154.000000      43.750000
# 50%               NaN     778.000000     391.000000      49.170000
# 75%               NaN     985.000000     521.000000      55.000000
# max               NaN  124754.000000   97750.000000     100.000000
#
#               Votants      % Vot/Ins         Blancs   % Blancs/Ins  \
# count   740387.000000  740387.000000  740387.000000  740387.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean       342.026158      50.062519       5.291368       0.841793
# std        306.675039      10.138161       4.671860       0.769636
# min          0.000000       0.000000       0.000000       0.000000
# 25%        165.000000      45.000000       2.000000       0.400000
# 50%        346.000000      50.830000       5.000000       0.690000
# 75%        477.000000      56.250000       8.000000       1.090000
# max      29796.000000     100.000000     270.000000      32.650000
#
#          % Blancs/Vot           Nuls     % Nuls/Ins     % Nuls/Vot  \
# count   740387.000000  740387.000000  740387.000000  740387.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         1.702443       2.221526       0.362178       0.761411
# std          1.402516       2.645938       0.531870       1.134285
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.840000       0.000000       0.000000       0.000000
# 50%          1.450000       2.000000       0.230000       0.480000
# 75%          2.230000       3.000000       0.470000       0.970000
# max         48.480000     152.000000      25.680000      83.330000
#
#              Exprimés      % Exp/Ins      % Exp/Vot      N°Panneau    Sexe  \
# count   740387.000000  740387.000000  740387.000000  740387.000000  740387
# unique            NaN            NaN            NaN            NaN       2
# top               NaN            NaN            NaN            NaN       M
# freq              NaN            NaN            NaN            NaN  415573
# mean       334.513264      48.858529      97.532092       6.005870     NaN
# std        302.932263       9.997950       2.020639       3.393082     NaN
# min          0.000000       0.000000       0.000000       1.000000     NaN
# 25%        160.000000      43.940000      96.910000       3.000000     NaN
# 50%        338.000000      49.640000      97.920000       6.000000     NaN
# 75%        467.000000      54.960000      98.660000       9.000000     NaN
# max      29560.000000     100.000000     100.000000      22.000000     NaN
#
#            Nom    Prénom  Nuance           Voix     % Voix/Ins % Voix/Exp  \
# count   740387    740387  740387  740387.000000  740387.000000     740387
# unique    5413      1551      16            NaN            NaN       6753
# top     MARTIN  Philippe     ECO            NaN            NaN       0.00
# freq      3292     11799   90246            NaN            NaN      77646
# mean       NaN       NaN     NaN      30.725878       4.628538        NaN
# std        NaN       NaN     NaN      59.902820       6.182793        NaN
# min        NaN       NaN     NaN       0.000000       0.000000        NaN
# 25%        NaN       NaN     NaN       3.000000       0.460000        NaN
# 50%        NaN       NaN     NaN       9.000000       1.500000        NaN
# 75%        NaN       NaN     NaN      35.000000       7.440000        NaN
# max        NaN       NaN     NaN   12578.000000     100.000000        NaN
#
#         Code Officiel EPCI         Nom Officiel EPCI  Code Officiel Région  \
# count         7.332280e+05                    733228         733472.000000
# unique                 NaN                      1251                   NaN
# top                    NaN  Métropole du Grand Paris                   NaN
# freq                   NaN                     44320                   NaN
# mean          2.152834e+08                       NaN             51.008315
# std           2.138700e+07                       NaN             31.557165
# min           2.000002e+08                       NaN              1.000000
# 25%           2.000548e+08                       NaN             28.000000
# 50%           2.000695e+08                       NaN             52.000000
# 75%           2.432006e+08                       NaN             76.000000
# max           2.497401e+08                       NaN            978.000000
#
#        Nom Officiel Région             location lib_du_b_vote scrutin_code
# count               733472               697597        703568       740387
# unique                  21                42333         29540            1
# top          Île-de-France  48.579831, 7.761454        MAIRIE       LG2022
# freq                 84670                 2186        105144       740387
# mean                   NaN                  NaN           NaN          NaN
# std                    NaN                  NaN           NaN          NaN
# min                    NaN                  NaN           NaN          NaN
# 25%                    NaN                  NaN           NaN          NaN
# 50%                    NaN                  NaN           NaN          NaN
# 75%                    NaN                  NaN           NaN          NaN
# max                    NaN                  NaN           NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740387 entries, 0 to 740386
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Code du département            740387 non-null  object
#  1   Libellé du département         740387 non-null  object
#  2   Code de la circonscription     740387 non-null  int64
#  3   Libellé de la circonscription  740387 non-null  object
#  4   Code de la commune             740387 non-null  object
#  5   Libellé de la commune          740387 non-null  object
#  6   Code du b.vote                 740387 non-null  object
#  7   Inscrits                       740387 non-null  int64
#  8   Abstentions                    740387 non-null  int64
#  9   % Abs/Ins                      740387 non-null  float64
#  10  Votants                        740387 non-null  int64
#  11  % Vot/Ins                      740387 non-null  float64
#  12  Blancs                         740387 non-null  int64
#  13  % Blancs/Ins                   740387 non-null  float64
#  14  % Blancs/Vot                   740387 non-null  float64
#  15  Nuls                           740387 non-null  int64
#  16  % Nuls/Ins                     740387 non-null  float64
#  17  % Nuls/Vot                     740387 non-null  float64
#  18  Exprimés                       740387 non-null  int64
#  19  % Exp/Ins                      740387 non-null  float64
#  20  % Exp/Vot                      740387 non-null  float64
#  21  N°Panneau                      740387 non-null  int64
#  22  Sexe                           740387 non-null  object
#  23  Nom                            740387 non-null  object
#  24  Prénom                         740387 non-null  object
#  25  Nuance                         740387 non-null  object
#  26  Voix                           740387 non-null  int64
#  27  % Voix/Ins                     740387 non-null  float64
#  28  % Voix/Exp                     740387 non-null  string
#  29  Code Officiel EPCI             733228 non-null  float64
#  30  Nom Officiel EPCI              733228 non-null  object
#  31  Code Officiel Région           733472 non-null  float64
#  32  Nom Officiel Région            733472 non-null  object
#  33  location                       697597 non-null  object
#  34  lib_du_b_vote                  703568 non-null  object
#  35  scrutin_code                   740387 non-null  object
# dtypes: float64(11), int64(9), object(15), string(1)
# memory usage: 203.4+ MB

# %%
df_separato = df['location'].str.split(',', expand=True)
df_separato.columns = ['Latitudine', 'Longitudine']
df_separato.head()
# Out:
#   Latitudine Longitudine
# 0  43.415837    5.220936
# 1  43.415837    5.220936
# 2  43.415837    5.220936
# 3  43.415837    5.220936
# 4  43.415837    5.220936

# %%
df = pd.concat([df, df_separato], axis=1)
df = df.drop('location',axis = 1)
df.head()
# Out:
#   Code du département Libellé du département  Code de la circonscription  \
# 0                  13       Bouches-du-Rhône                          12
# 1                  13       Bouches-du-Rhône                          12
# 2                  13       Bouches-du-Rhône                          12
# 3                  13       Bouches-du-Rhône                          12
# 4                  13       Bouches-du-Rhône                          12
#
#   Libellé de la circonscription Code de la commune Libellé de la commune  \
# 0         12ème circonscription              13054             Marignane
# 1         12ème circonscription              13054             Marignane
# 2         12ème circonscription              13054             Marignane
# 3         12ème circonscription              13054             Marignane
# 4         12ème circonscription              13054             Marignane
#
#   Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0             17       935          547      58.50      388      41.50
# 1             19       862          448      51.97      414      48.03
# 2             20       984          648      65.85      336      34.15
# 3             21       604          372      61.59      232      38.41
# 4             23       980          652      66.53      328      33.47
#
#    Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins  % Nuls/Vot  Exprimés  \
# 0       7          0.75          1.80     0         0.0         0.0       381
# 1      11          1.28          2.66     0         0.0         0.0       403
# 2      12          1.22          3.57     0         0.0         0.0       324
# 3       2          0.33          0.86     0         0.0         0.0       230
# 4       7          0.71          2.13     0         0.0         0.0       321
#
#    % Exp/Ins  % Exp/Vot  N°Panneau Sexe        Nom    Prénom Nuance  Voix  \
# 0      40.75      98.20          8    M    RIBEIRO  Stéphane    ECO     2
# 1      46.75      97.34          3    M  DELESPAUL     Hervé    DSV     8
# 2      32.93      96.43          3    M  DELESPAUL     Hervé    DSV     4
# 3      38.08      99.14          5    M      ROCHE  François    DXG     1
# 4      32.76      97.87          8    M    RIBEIRO  Stéphane    ECO     4
#
#    % Voix/Ins % Voix/Exp  Code Officiel EPCI  \
# 0        0.21       0.52         200054807.0
# 1        0.93       1.99         200054807.0
# 2        0.41       1.23         200054807.0
# 3        0.17       0.43         200054807.0
# 4        0.41       1.25         200054807.0
#
#                     Nom Officiel EPCI  Code Officiel Région  \
# 0  Métropole d'Aix-Marseille-Provence                  93.0
# 1  Métropole d'Aix-Marseille-Provence                  93.0
# 2  Métropole d'Aix-Marseille-Provence                  93.0
# 3  Métropole d'Aix-Marseille-Provence                  93.0
# 4  Métropole d'Aix-Marseille-Provence                  93.0
#
#           Nom Officiel Région                     lib_du_b_vote scrutin_code  \
# 0  Provence-Alpes-Côte d'Azur         PARC DES SPORTS DU BOLMON       LG2022
# 1  Provence-Alpes-Côte d'Azur  CENTRE SOCIO CULT J RAIMU LE JAI       LG2022
# 2  Provence-Alpes-Côte d'Azur              GYMNASE DU CARESTIER       LG2022
# 3  Provence-Alpes-Côte d'Azur              GYMNASE DU CARESTIER       LG2022
# 4  Provence-Alpes-Côte d'Azur         PARC DES SPORTS DU BOLMON       LG2022
#
#   Latitudine Longitudine
# 0  43.415837    5.220936
# 1  43.415837    5.220936
# 2  43.415837    5.220936
# 3  43.415837    5.220936
# 4  43.415837    5.220936

# %%
duplicati_presenti = df.duplicated().any()

if duplicati_presenti:
    print("Sono presenti duplicati nel DataFrame.")
else:
    print("Non ci sono duplicati nel DataFrame.")
# Out:
# Non ci sono duplicati nel DataFrame.

# %% [markdown]
# ## 1.2.Gestione dei valori nulli

# %%
#Rimuovo le righe con il nome della regione nullo
df = df.dropna(subset=['Nom Officiel Région'])

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Code du département  Libellé du département  Code de la circonscription  \
# 0                False                   False                       False
# 1                False                   False                       False
# 2                False                   False                       False
# 3                False                   False                       False
# 4                False                   False                       False
#
#    Libellé de la circonscription  Code de la commune  Libellé de la commune  \
# 0                          False               False                  False
# 1                          False               False                  False
# 2                          False               False                  False
# 3                          False               False                  False
# 4                          False               False                  False
#
#    Code du b.vote  Inscrits  Abstentions  % Abs/Ins  Votants  % Vot/Ins  \
# 0           False     False        False      False    False      False
# 1           False     False        False      False    False      False
# 2           False     False        False      False    False      False
# 3           False     False        False      False    False      False
# 4           False     False        False      False    False      False
#
#    Blancs  % Blancs/Ins  % Blancs/Vot   Nuls  % Nuls/Ins  % Nuls/Vot  \
# 0   False         False         False  False       False       False
# 1   False         False         False  False       False       False
# 2   False         False         False  False       False       False
# 3   False         False         False  False       False       False
# 4   False         False         False  False       False       False
#
#    Exprimés  % Exp/Ins  % Exp/Vot  N°Panneau   Sexe    Nom  Prénom  Nuance  \
# 0     False      False      False      False  False  False   False   False
# 1     False      False      False      False  False  False   False   False
# 2     False      False      False      False  False  False   False   False
# 3     False      False      False      False  False  False   False   False
# 4     False      False      False      False  False  False   False   False
#
#     Voix  % Voix/Ins  % Voix/Exp  Code Officiel EPCI  Nom Officiel EPCI  \
# 0  False       False       False               False              False
# 1  False       False       False               False              False
# 2  False       False       False               False              False
# 3  False       False       False               False              False
# 4  False       False       False               False              False
#
#    Code Officiel Région  Nom Officiel Région  lib_du_b_vote  scrutin_code  \
# 0                 False                False          False         False
# 1                 False                False          False         False
# 2                 False                False          False         False
# 3                 False                False          False         False
# 4                 False                False          False         False
#
#    Latitudine  Longitudine
# 0       False        False
# 1       False        False
# 2       False        False
# 3       False        False
# 4       False        False

# %%
for column in missing_data.columns.values.tolist():
    #print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# False    733472
# Name: Code du département, dtype: int64
#
# False    733472
# Name: Libellé du département, dtype: int64
#
# False    733472
# Name: Code de la circonscription, dtype: int64
#
# False    733472
# Name: Libellé de la circonscription, dtype: int64
#
# False    733472
# Name: Code de la commune, dtype: int64
#
# False    733472
# Name: Libellé de la commune, dtype: int64
#
# False    733472
# Name: Code du b.vote, dtype: int64
#
# False    733472
# Name: Inscrits, dtype: int64
#
# False    733472
# Name: Abstentions, dtype: int64
#
# False    733472
# Name: % Abs/Ins, dtype: int64
#
# False    733472
# Name: Votants, dtype: int64
#
# False    733472
# Name: % Vot/Ins, dtype: int64
#
# False    733472
# Name: Blancs, dtype: int64
#
# False    733472
# Name: % Blancs/Ins, dtype: int64
#
# False    733472
# Name: % Blancs/Vot, dtype: int64
#
# False    733472
# Name: Nuls, dtype: int64
#
# False    733472
# Name: % Nuls/Ins, dtype: int64
#
# False    733472
# Name: % Nuls/Vot, dtype: int64
#
# False    733472
# Name: Exprimés, dtype: int64
#
# False    733472
# Name: % Exp/Ins, dtype: int64
#
# False    733472
# Name: % Exp/Vot, dtype: int64
#
# False    733472
# Name: N°Panneau, dtype: int64
#
# False    733472
# Name: Sexe, dtype: int64
#
# False    733472
# Name: Nom, dtype: int64
#
# False    733472
# Name: Prénom, dtype: int64
#
# False    733472
# Name: Nuance, dtype: int64
#
# False    733472
# Name: Voix, dtype: int64
#
# False    733472
# Name: % Voix/Ins, dtype: int64
#
# False    733472
# Name: % Voix/Exp, dtype: int64
#
# False    733228
# True        244
# Name: Code Officiel EPCI, dtype: int64
#
# False    733228
# True        244
# Name: Nom Officiel EPCI, dtype: int64
#
# False    733472
# Name: Code Officiel Région, dtype: int64
#
# False    733472
# Name: Nom Officiel Région, dtype: int64
#
# False    703568
# True      29904
# Name: lib_du_b_vote, dtype: int64
#
# False    733472
# Name: scrutin_code, dtype: int64
#
# False    697597
# True      35875
# Name: Latitudine, dtype: int64
#
# False    697597
# True      35875
# Name: Longitudine, dtype: int64

# %%
df = df.drop('lib_du_b_vote',axis = 1)

# %% [markdown]
# ## 1.3.Gestione dei tipi

# %%
df.dtypes
# Out:
# Code du département               object
# Libellé du département            object
# Code de la circonscription         int64
# Libellé de la circonscription     object
# Code de la commune                object
# Libellé de la commune             object
# Code du b.vote                    object
# Inscrits                           int64
# Abstentions                        int64
# % Abs/Ins                        float64
# Votants                            int64
# % Vot/Ins                        float64
# Blancs                             int64
# % Blancs/Ins                     float64
# % Blancs/Vot                     float64
# Nuls                               int64
# % Nuls/Ins                       float64
# % Nuls/Vot                       float64
# Exprimés                           int64
# % Exp/Ins                        float64
# % Exp/Vot                        float64
# N°Panneau                          int64
# Sexe                              object
# Nom                               object
# Prénom                            object
# Nuance                            object
# Voix                               int64
# % Voix/Ins                       float64
# % Voix/Exp                        string
# Code Officiel EPCI               float64
# Nom Officiel EPCI                 object
# Code Officiel Région             float64
# Nom Officiel Région               object
# scrutin_code                      object
# Latitudine                        object
# Longitudine                       object
# dtype: object

# %%
df[['Code du département','Code de la commune', 'Code du b.vote']] = df[['Code du département','Code de la commune', 'Code du b.vote']].astype("string")
df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune',
    'Sexe','Nom','Prénom','Nuance','Nom Officiel Région','scrutin_code']] = df[['Libellé du département','Libellé de la circonscription', 'Libellé de la commune',
                                                        'Sexe','Nom','Prénom','Nuance','Nom Officiel Région','scrutin_code']].astype("string")
df[['Latitudine','Longitudine','% Voix/Exp']] = df[['Latitudine','Longitudine','% Voix/Exp']].astype('float')

# %%
df.dtypes
# Out:
# Code du département               string
# Libellé du département            string
# Code de la circonscription         int64
# Libellé de la circonscription     string
# Code de la commune                string
# Libellé de la commune             string
# Code du b.vote                    string
# Inscrits                           int64
# Abstentions                        int64
# % Abs/Ins                        float64
# Votants                            int64
# % Vot/Ins                        float64
# Blancs                             int64
# % Blancs/Ins                     float64
# % Blancs/Vot                     float64
# Nuls                               int64
# % Nuls/Ins                       float64
# % Nuls/Vot                       float64
# Exprimés                           int64
# % Exp/Ins                        float64
# % Exp/Vot                        float64
# N°Panneau                          int64
# Sexe                              string
# Nom                               string
# Prénom                            string
# Nuance                            string
# Voix                               int64
# % Voix/Ins                       float64
# % Voix/Exp                       float64
# Code Officiel EPCI               float64
# Nom Officiel EPCI                 object
# Code Officiel Région             float64
# Nom Officiel Région               string
# scrutin_code                      string
# Latitudine                       float64
# Longitudine                      float64
# dtype: object

# %% [markdown]
# ## 1.4 Eliminazione dei dipartimenti del gruppo 1

# %%
df.shape
# Out:
# (733472, 36)

# %%
df = df.drop(df[df['Nom Officiel Région'] == 'Hauts-de-France'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Grand Est'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Île-de-France'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Normandie'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Bretagne'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Bourgogne-Franche-Comté'].index)
df = df.drop(df[df['Nom Officiel Région'] == 'Centre-Val de Loire'].index)

# %%
lista_nome_regioni = df['Nom Officiel Région'].unique()
print(lista_nome_regioni)
print(df.shape)
# Out:
# <StringArray>
# ["Provence-Alpes-Côte d'Azur",       'Auvergne-Rhône-Alpes',
#                   'Occitanie',         'Nouvelle-Aquitaine',
#                       'Corse',           'Pays de la Loire',
#                  'La Réunion',                    'Mayotte',
#            'Saint-Barthélemy',               'Saint-Martin',
#                  'Guadeloupe',                 'Martinique',
#                      'Guyane',   'Saint-Pierre-et-Miquelon']
# Length: 14, dtype: string
# (358246, 36)

# %%
lista_dipartimenti = df['Libellé du département'].unique()
print(lista_dipartimenti)
lista_dipartimenti.size
# Out:
# <StringArray>
# [               'Bouches-du-Rhône',                             'Ain',
#                  'Alpes-Maritimes',         'Alpes-de-Haute-Provence',
#                     'Hautes-Alpes',                            'Aude',
#                          'Aveyron',                    'Haute-Savoie',
#                  'Hautes-Pyrénées',             'Pyrénées-Orientales',
#                          'Corrèze',                    'Corse-du-Sud',
#                      'Haute-Corse',                            'Tarn',
#                  'Tarn-et-Garonne',                    'Haute-Vienne',
#                           'Sarthe',                          'Savoie',
#                       'La Réunion',                         'Mayotte',
#    'Saint-Martin/Saint-Barthélemy', 'Français établis hors de France',
#                           'Allier',                          'Ariège',
#                            'Rhône',            'Pyrénées-Atlantiques',
#                           'Vendée',                          'Vienne',
#                      'Deux-Sèvres',                             'Var',
#                         'Vaucluse',                      'Guadeloupe',
#                       'Martinique',                          'Guyane',
#                'Charente-Maritime',                          'Cantal',
#                         'Charente',                         'Ardèche',
#                      'Puy-de-Dôme',                            'Gers',
#                          'Gironde',                           'Isère',
#                           'Landes',                           'Loire',
#                      'Haute-Loire',                'Loire-Atlantique',
#                          'Hérault',                          'Creuse',
#                         'Dordogne',                           'Drôme',
#                    'Haute-Garonne',                            'Gard',
#                          'Mayenne',                             'Lot',
#                   'Lot-et-Garonne',                          'Lozère',
#                   'Maine-et-Loire',              'Nouvelle-Calédonie',
#         'Saint-Pierre-et-Miquelon']
# Length: 59, dtype: string
# 59

# %% [markdown]
# ## 1.6.Salvataggio del dataSet pulito

# %%
path = '/content/drive/Shareddrives/Progetto Big Data/DataSet Puliti/legislatives-2022-1er-tour_cleaned.csv'
df.to_csv(path,index=False , sep = ';');
